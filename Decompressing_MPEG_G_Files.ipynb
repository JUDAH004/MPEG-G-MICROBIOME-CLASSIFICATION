# %% [markdown]
# # Unzipping the Train and Test folders and view the MPEG-G files

# %%
# Test Docker works
# !docker run hello-world
# Out:
# Hello from Docker!
# This message shows that your installation appears to be working correctly.
#
# To generate this message, Docker took the following steps:
#  1. The Docker client contacted the Docker daemon.
#  2. The Docker daemon pulled the "hello-world" image from the Docker Hub.
#     (amd64)
#  3. The Docker daemon created a new container from that image which runs the
#     executable that produces the output you are currently reading.
#  4. The Docker daemon streamed that output to the Docker client, which sent it
#     to your terminal.
#
# To try something more ambitious, you can run an Ubuntu container with:
#  $ docker run -it ubuntu bash
#
# Share images, automate workflows, and more with a free Docker ID:
#  https://hub.docker.com/
#
# For more examples and ideas, visit:
#  https://docs.docker.com/get-started/

# %%
# %pip install Bio
# Out:
# Requirement already satisfied: Bio in c:\users\judah\anaconda3\envs\learn-env\lib\site-packages (1.6.2)
# Requirement already satisfied: biopython>=1.80 in c:\users\judah\anaconda3\envs\learn-env\lib\site-packages (from Bio) (1.83)
# Requirement already satisfied: tqdm in c:\users\judah\anaconda3\envs\learn-env\lib\site-packages (from Bio) (4.50.2)
# Requirement already satisfied: pooch in c:\users\judah\anaconda3\envs\learn-env\lib\site-packages (from Bio) (1.8.2)
# Requirement already satisfied: requests in c:\users\judah\anaconda3\envs\learn-env\lib\site-packages (from Bio) (2.32.4)
# Requirement already satisfied: pandas in c:\users\judah\anaconda3\envs\learn-env\lib\site-packages (from Bio) (2.0.3)
# Requirement already satisfied: gprofiler-official in c:\users\judah\anaconda3\envs\learn-env\lib\site-packages (from Bio) (1.0.0)
# Requirement already satisfied: mygene in c:\users\judah\anaconda3\envs\learn-env\lib\site-packages (from Bio) (3.2.2)
# Requirement already satisfied: numpy in c:\users\judah\anaconda3\envs\learn-env\lib\site-packages (from biopython>=1.80->Bio) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\judah\anaconda3\envs\learn-env\lib\site-packages (from pooch->Bio) (24.2)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\judah\anaconda3\envs\learn-env\lib\site-packages (from pooch->Bio) (4.3.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\judah\anaconda3\envs\learn-env\lib\site-packages (from requests->Bio) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\judah\anaconda3\envs\learn-env\lib\site-packages (from requests->Bio) (2.10)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\judah\anaconda3\envs\learn-env\lib\site-packages (from requests->Bio) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\judah\anaconda3\envs\learn-env\lib\site-packages (from requests->Bio) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\judah\anaconda3\envs\learn-env\lib\site-packages (from pandas->Bio) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\judah\anaconda3\envs\learn-env\lib\site-packages (from pandas->Bio) (2020.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\judah\anaconda3\envs\learn-env\lib\site-packages (from pandas->Bio) (2025.2)
# Requirement already satisfied: biothings-client>=0.2.6 in c:\users\judah\anaconda3\envs\learn-env\lib\site-packages (from mygene->Bio) (0.4.1)
# Requirement already satisfied: six>=1.5 in c:\users\judah\anaconda3\envs\learn-env\lib\site-packages (from python-dateutil>=2.8.2->pandas->Bio) (1.15.0)
# Requirement already satisfied: httpx>=0.22.0 in c:\users\judah\anaconda3\envs\learn-env\lib\site-packages (from biothings-client>=0.2.6->mygene->Bio) (0.28.1)
# Requirement already satisfied: anyio in c:\users\judah\anaconda3\envs\learn-env\lib\site-packages (from httpx>=0.22.0->biothings-client>=0.2.6->mygene->Bio) (4.5.2)
# Requirement already satisfied: httpcore==1.* in c:\users\judah\anaconda3\envs\learn-env\lib\site-packages (from httpx>=0.22.0->biothings-client>=0.2.6->mygene->Bio) (1.0.9)
# Requirement already satisfied: typing-extensions>=4.1; python_version < "3.11" in c:\users\judah\anaconda3\envs\learn-env\lib\site-packages (from anyio->httpx>=0.22.0->biothings-client>=0.2.6->mygene->Bio) (4.13.2)
# Requirement already satisfied: exceptiongroup>=1.0.2; python_version < "3.11" in c:\users\judah\anaconda3\envs\learn-env\lib\site-packages (from anyio->httpx>=0.22.0->biothings-client>=0.2.6->mygene->Bio) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\judah\anaconda3\envs\learn-env\lib\site-packages (from anyio->httpx>=0.22.0->biothings-client>=0.2.6->mygene->Bio) (1.3.1)
# Requirement already satisfied: h11>=0.16 in c:\users\judah\anaconda3\envs\learn-env\lib\site-packages (from httpcore==1.*->httpx>=0.22.0->biothings-client>=0.2.6->mygene->Bio) (0.16.0)

# %%
# Import packages
import os
import zipfile
import subprocess
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import shutil


from Bio import SeqIO
from collections import Counter

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report

# Errors ignore
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Step 1. Extract the Train and Test File from a .zip

# %%
print(os.listdir('.'))
# Out:
# ['Starter_NB_Part1_Decompressing_MPEG_G_files.ipynb']

# %%
# Define your zip files and corresponding output directories
zip_targets = {
    r"C:\Users\JUDAH\Downloads\TrainFiles.zip": './train',
    r"C:\Users\JUDAH\Downloads\TestFiles.zip": './test'
}

for zip_path, extract_to in zip_targets.items():
    # Create the output directory if it doesn't exist
    os.makedirs(extract_to, exist_ok=True)

    try:
        # Use shutil to extract
        shutil.unpack_archive(zip_path, extract_to, format='zip')
        print(f"✅ Successfully extracted {zip_path} to ./{extract_to}/")
    except Exception as e:
        print(f"❌ Failed to extract {zip_path}: {e}")
# Out:
# ✅ Successfully extracted C:\Users\JUDAH\Downloads\TrainFiles.zip to ././train/
# ✅ Successfully extracted C:\Users\JUDAH\Downloads\TestFiles.zip to ././test/

# %% [markdown]
# ##  Step 2: Pull the Genie Docker Image

# %%
# Ensure you have the latest version of Genie
# !docker pull muefab/genie:latest
# Out:
# latest: Pulling from muefab/genie
# b0907bbb508f: Pulling fs layer
# 4619a895afbd: Pulling fs layer
# 0a9a5dfd008f: Pulling fs layer
# 846abc99b13f: Pulling fs layer
# 4f4fb700ef54: Pulling fs layer
# bb6c686a0e98: Pulling fs layer
# 4f4fb700ef54: Download complete
# 0a9a5dfd008f: Download complete
# b0907bbb508f: Download complete
# 4619a895afbd: Download complete
# 0a9a5dfd008f: Pull complete
# 846abc99b13f: Download complete
# bb6c686a0e98: Download complete
# bb6c686a0e98: Pull complete
# 4619a895afbd: Pull complete
# 846abc99b13f: Pull complete
# b0907bbb508f: Pull complete
# 4f4fb700ef54: Pull complete
# Digest: sha256:c3112a3879cc18061bbab5ed8f76dec255ab1be46e2133cd59320dd5ba98ef89
# Status: Downloaded newer image for muefab/genie:latest
# docker.io/muefab/genie:latest

# %% [markdown]
# ###  Step 3: Write a function to decode the mgb files

# %%
import os
import subprocess
import gzip
import shutil

# Set base directories
notebook_dir = os.getcwd()
container_dir = "/data"

# Function to decode all `.mgb` files in their respective folder
def decode_all_mgb_in_folder(folder_name):
    host_dir = os.path.join(notebook_dir, folder_name)
    
    for mgb_filename in os.listdir(host_dir):
        if not mgb_filename.endswith(".mgb"):
            continue

        mgb_path = os.path.join(host_dir, mgb_filename)
        mgb_filename_no_ext = os.path.splitext(mgb_filename)[0]
        fastq_path = os.path.join(host_dir, f"{mgb_filename_no_ext}.fastq")
        fastq_gz_path = f"{fastq_path}.gz"

        command = [
            "docker", "run", "--rm",
            "-v", f"{host_dir}:{container_dir}",
            "muefab/genie:latest", "run",
            "-f",
            "-i", f"{container_dir}/{mgb_filename}",
            "-o", f"{container_dir}/{mgb_filename_no_ext}.fastq"
        ]

        subprocess.run(command, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

        if not os.path.exists(fastq_path):
            print(f"[Error] FASTQ not created: {mgb_filename}")
            continue

        try:
            with open(fastq_path, "rb") as f_in, gzip.open(fastq_gz_path, "wb") as f_out:
                shutil.copyfileobj(f_in, f_out)
        except Exception as e:
            print(f"[Error] Compression failed: {mgb_filename} - {str(e)}")
            continue

        os.remove(mgb_path)# delete the original `.mgb` file
        os.remove(fastq_path) #delete the uncompressed FASTQ file

        print(f"[OK] {mgb_filename} → {os.path.basename(fastq_gz_path)}")
            
        """
        Caution on printing out each line as this does take up memory.

        print("\n--- STDOUT ---\n")
        print(result.stdout)
        if result.stderr:
            print("\n--- STDERR ---\n")
            print(result.stderr)#

        """

# %% [markdown]
# ###  Step 4: Use function to decode the mgb files

# %%
decode_all_mgb_in_folder(r"C:\Users\JUDAH\Desktop\Mircobiome MPEG\train\TrainFiles")
decode_all_mgb_in_folder(r"C:\Users\JUDAH\Desktop\Mircobiome MPEG\test\TestFiles")
# Out:
# [OK] ID_AAFNOT.mgb → ID_AAFNOT.fastq.gz
# [OK] ID_AAXPTO.mgb → ID_AAXPTO.fastq.gz
# [OK] ID_AAYKAN.mgb → ID_AAYKAN.fastq.gz
# [OK] ID_ABEZNS.mgb → ID_ABEZNS.fastq.gz
# [OK] ID_ABFFLP.mgb → ID_ABFFLP.fastq.gz
# [OK] ID_ABFQPG.mgb → ID_ABFQPG.fastq.gz
# [OK] ID_ABMLPB.mgb → ID_ABMLPB.fastq.gz
# [OK] ID_ABOEMW.mgb → ID_ABOEMW.fastq.gz
# [OK] ID_ABRMNZ.mgb → ID_ABRMNZ.fastq.gz
# [OK] ID_ABROLI.mgb → ID_ABROLI.fastq.gz
# [OK] ID_ABYEPC.mgb → ID_ABYEPC.fastq.gz
# [OK] ID_ABYUSV.mgb → ID_ABYUSV.fastq.gz
# [OK] ID_ABZIIM.mgb → ID_ABZIIM.fastq.gz
# [OK] ID_ACDYOS.mgb → ID_ACDYOS.fastq.gz
# [OK] ID_ACFOIY.mgb → ID_ACFOIY.fastq.gz
# [OK] ID_ACKYNO.mgb → ID_ACKYNO.fastq.gz
# [OK] ID_ACNBRX.mgb → ID_ACNBRX.fastq.gz
# [OK] ID_ACPNZE.mgb → ID_ACPNZE.fastq.gz
# [OK] ID_ACSAGK.mgb → ID_ACSAGK.fastq.gz
# [OK] ID_ACWUII.mgb → ID_ACWUII.fastq.gz
# [OK] ID_ADDBVX.mgb → ID_ADDBVX.fastq.gz
# [OK] ID_ADGTHC.mgb → ID_ADGTHC.fastq.gz
# [OK] ID_AEHLIF.mgb → ID_AEHLIF.fastq.gz
# [OK] ID_AEWEDE.mgb → ID_AEWEDE.fastq.gz
# [OK] ID_AFDWVD.mgb → ID_AFDWVD.fastq.gz
# [OK] ID_AFHPCO.mgb → ID_AFHPCO.fastq.gz
# [OK] ID_AFZILT.mgb → ID_AFZILT.fastq.gz
# [OK] ID_AGAGLA.mgb → ID_AGAGLA.fastq.gz
# [OK] ID_AGQNUI.mgb → ID_AGQNUI.fastq.gz
# [OK] ID_AGXZQZ.mgb → ID_AGXZQZ.fastq.gz
# [OK] ID_AHFGJR.mgb → ID_AHFGJR.fastq.gz
# [OK] ID_AHHREZ.mgb → ID_AHHREZ.fastq.gz
# [OK] ID_AHKUAJ.mgb → ID_AHKUAJ.fastq.gz
# [OK] ID_AHLLIA.mgb → ID_AHLLIA.fastq.gz
# [OK] ID_AHRTSW.mgb → ID_AHRTSW.fastq.gz
# [OK] ID_AIGSFE.mgb → ID_AIGSFE.fastq.gz
# [OK] ID_AIJXHS.mgb → ID_AIJXHS.fastq.gz
# [OK] ID_AILQVW.mgb → ID_AILQVW.fastq.gz
# [OK] ID_AIUTRN.mgb → ID_AIUTRN.fastq.gz
# [OK] ID_AIUTYM.mgb → ID_AIUTYM.fastq.gz
# [OK] ID_AIZFSP.mgb → ID_AIZFSP.fastq.gz
# [OK] ID_AJBMTW.mgb → ID_AJBMTW.fastq.gz
# [OK] ID_AJCSAH.mgb → ID_AJCSAH.fastq.gz
# [OK] ID_AJNJUL.mgb → ID_AJNJUL.fastq.gz
# [OK] ID_AJSRSU.mgb → ID_AJSRSU.fastq.gz
# [OK] ID_AKEPQD.mgb → ID_AKEPQD.fastq.gz
# [OK] ID_AKNECU.mgb → ID_AKNECU.fastq.gz
# [OK] ID_AKOUSJ.mgb → ID_AKOUSJ.fastq.gz
# [OK] ID_AKSAFQ.mgb → ID_AKSAFQ.fastq.gz
# [OK] ID_ALHJLQ.mgb → ID_ALHJLQ.fastq.gz
# [OK] ID_ALJECR.mgb → ID_ALJECR.fastq.gz
# [OK] ID_ALSOFJ.mgb → ID_ALSOFJ.fastq.gz
# [OK] ID_ALXHDM.mgb → ID_ALXHDM.fastq.gz
# [OK] ID_ALXTCO.mgb → ID_ALXTCO.fastq.gz
# [OK] ID_AMDDPN.mgb → ID_AMDDPN.fastq.gz
# [OK] ID_AMHXQL.mgb → ID_AMHXQL.fastq.gz
# [OK] ID_AMMKIS.mgb → ID_AMMKIS.fastq.gz
# [OK] ID_AMNOGS.mgb → ID_AMNOGS.fastq.gz
# [OK] ID_AMQVHE.mgb → ID_AMQVHE.fastq.gz
# [OK] ID_AMXBLL.mgb → ID_AMXBLL.fastq.gz
# [OK] ID_ANGJFJ.mgb → ID_ANGJFJ.fastq.gz
# [OK] ID_ANRCHW.mgb → ID_ANRCHW.fastq.gz
# [OK] ID_AOANMO.mgb → ID_AOANMO.fastq.gz
# [OK] ID_AOCWNX.mgb → ID_AOCWNX.fastq.gz
# [OK] ID_AOFWAD.mgb → ID_AOFWAD.fastq.gz
# [OK] ID_AOITMX.mgb → ID_AOITMX.fastq.gz
# [OK] ID_AOKDRE.mgb → ID_AOKDRE.fastq.gz
# [OK] ID_AOLYKG.mgb → ID_AOLYKG.fastq.gz
# [OK] ID_AOOKYO.mgb → ID_AOOKYO.fastq.gz
# [OK] ID_AOSCCM.mgb → ID_AOSCCM.fastq.gz
# [OK] ID_AOTUJU.mgb → ID_AOTUJU.fastq.gz
# [OK] ID_APSXJV.mgb → ID_APSXJV.fastq.gz
# [OK] ID_AQHGSF.mgb → ID_AQHGSF.fastq.gz
# [OK] ID_AQLAFV.mgb → ID_AQLAFV.fastq.gz
# [OK] ID_AQLRBI.mgb → ID_AQLRBI.fastq.gz
# [OK] ID_AQUPQC.mgb → ID_AQUPQC.fastq.gz
# [OK] ID_AQZMOJ.mgb → ID_AQZMOJ.fastq.gz
# [OK] ID_ARKGAH.mgb → ID_ARKGAH.fastq.gz
# [OK] ID_ARRIGW.mgb → ID_ARRIGW.fastq.gz
# [OK] ID_ARRPME.mgb → ID_ARRPME.fastq.gz
# [OK] ID_ARTGPP.mgb → ID_ARTGPP.fastq.gz
# [OK] ID_ARUNMM.mgb → ID_ARUNMM.fastq.gz
# [OK] ID_ARYFGN.mgb → ID_ARYFGN.fastq.gz
# [OK] ID_ASOJIQ.mgb → ID_ASOJIQ.fastq.gz
# [OK] ID_ASOYXX.mgb → ID_ASOYXX.fastq.gz
# [OK] ID_ASUWQJ.mgb → ID_ASUWQJ.fastq.gz
# [OK] ID_ASZQOD.mgb → ID_ASZQOD.fastq.gz
# [OK] ID_ATBWZJ.mgb → ID_ATBWZJ.fastq.gz
# [OK] ID_ATCYGQ.mgb → ID_ATCYGQ.fastq.gz
# [OK] ID_ATOCRR.mgb → ID_ATOCRR.fastq.gz
# [OK] ID_ATQHPY.mgb → ID_ATQHPY.fastq.gz
# [OK] ID_ATRUUE.mgb → ID_ATRUUE.fastq.gz
# [OK] ID_ATSANN.mgb → ID_ATSANN.fastq.gz
# [OK] ID_AVLZNJ.mgb → ID_AVLZNJ.fastq.gz
# [OK] ID_AVNKSZ.mgb → ID_AVNKSZ.fastq.gz
# [OK] ID_AVSCXA.mgb → ID_AVSCXA.fastq.gz
# [OK] ID_AWIWMI.mgb → ID_AWIWMI.fastq.gz
# [OK] ID_AWMVWH.mgb → ID_AWMVWH.fastq.gz
# [OK] ID_AWOZGF.mgb → ID_AWOZGF.fastq.gz
# [OK] ID_AWPWTE.mgb → ID_AWPWTE.fastq.gz
# [OK] ID_AXPAZY.mgb → ID_AXPAZY.fastq.gz
# [OK] ID_AXRWDA.mgb → ID_AXRWDA.fastq.gz
# [OK] ID_AXRZES.mgb → ID_AXRZES.fastq.gz
# [OK] ID_AXUMEQ.mgb → ID_AXUMEQ.fastq.gz
# [OK] ID_AXYRUO.mgb → ID_AXYRUO.fastq.gz
# [OK] ID_AYCGRQ.mgb → ID_AYCGRQ.fastq.gz
# [OK] ID_AYEWPT.mgb → ID_AYEWPT.fastq.gz
# [OK] ID_AYHIBL.mgb → ID_AYHIBL.fastq.gz
# [OK] ID_AYHLGO.mgb → ID_AYHLGO.fastq.gz
# [OK] ID_AYHRMP.mgb → ID_AYHRMP.fastq.gz
# [OK] ID_AYNMSB.mgb → ID_AYNMSB.fastq.gz
# [OK] ID_AYNXMD.mgb → ID_AYNXMD.fastq.gz
# [OK] ID_AYOTKS.mgb → ID_AYOTKS.fastq.gz
# [OK] ID_AYPACN.mgb → ID_AYPACN.fastq.gz
# [OK] ID_AYWJHN.mgb → ID_AYWJHN.fastq.gz
# [OK] ID_AYWSLB.mgb → ID_AYWSLB.fastq.gz
# [OK] ID_AZAARB.mgb → ID_AZAARB.fastq.gz
# [OK] ID_AZZSMR.mgb → ID_AZZSMR.fastq.gz
# [OK] ID_BAMZGX.mgb → ID_BAMZGX.fastq.gz
# [OK] ID_BASXMJ.mgb → ID_BASXMJ.fastq.gz
# [OK] ID_BATLNN.mgb → ID_BATLNN.fastq.gz
# [OK] ID_BAYRPN.mgb → ID_BAYRPN.fastq.gz
# [OK] ID_BAZXSK.mgb → ID_BAZXSK.fastq.gz
# [OK] ID_BBNWLY.mgb → ID_BBNWLY.fastq.gz
# [OK] ID_BBNYMC.mgb → ID_BBNYMC.fastq.gz
# [OK] ID_BBPEYX.mgb → ID_BBPEYX.fastq.gz
# [OK] ID_BBUIXC.mgb → ID_BBUIXC.fastq.gz
# [OK] ID_BBYKSG.mgb → ID_BBYKSG.fastq.gz
# [OK] ID_BCDPBO.mgb → ID_BCDPBO.fastq.gz
# [OK] ID_BCHMUF.mgb → ID_BCHMUF.fastq.gz
# [OK] ID_BCOHGF.mgb → ID_BCOHGF.fastq.gz
# [OK] ID_BCWAFO.mgb → ID_BCWAFO.fastq.gz
# [OK] ID_BCYOZW.mgb → ID_BCYOZW.fastq.gz
# [OK] ID_BDIHFC.mgb → ID_BDIHFC.fastq.gz
# [OK] ID_BDKLOC.mgb → ID_BDKLOC.fastq.gz
# [OK] ID_BDMAFZ.mgb → ID_BDMAFZ.fastq.gz
# [OK] ID_BDPILQ.mgb → ID_BDPILQ.fastq.gz
# [OK] ID_BDUKPO.mgb → ID_BDUKPO.fastq.gz
# [OK] ID_BDXMPE.mgb → ID_BDXMPE.fastq.gz
# [OK] ID_BEKTVZ.mgb → ID_BEKTVZ.fastq.gz
# [OK] ID_BFDOIX.mgb → ID_BFDOIX.fastq.gz
# [OK] ID_BFHQLE.mgb → ID_BFHQLE.fastq.gz
# [OK] ID_BFJJUV.mgb → ID_BFJJUV.fastq.gz
# [OK] ID_BFPKJO.mgb → ID_BFPKJO.fastq.gz
# [OK] ID_BFZKGB.mgb → ID_BFZKGB.fastq.gz
# [OK] ID_BFZNLF.mgb → ID_BFZNLF.fastq.gz
# [OK] ID_BGVFRI.mgb → ID_BGVFRI.fastq.gz
# [OK] ID_BGZYQJ.mgb → ID_BGZYQJ.fastq.gz
# [OK] ID_BHBSOA.mgb → ID_BHBSOA.fastq.gz
# [OK] ID_BHYLYB.mgb → ID_BHYLYB.fastq.gz
# [OK] ID_BIGCDY.mgb → ID_BIGCDY.fastq.gz
# [OK] ID_BILXIA.mgb → ID_BILXIA.fastq.gz
# [OK] ID_BIRZSY.mgb → ID_BIRZSY.fastq.gz
# [OK] ID_BJABXF.mgb → ID_BJABXF.fastq.gz
# [OK] ID_BJBUOY.mgb → ID_BJBUOY.fastq.gz
# [OK] ID_BJCMPA.mgb → ID_BJCMPA.fastq.gz
# [OK] ID_BJEDLO.mgb → ID_BJEDLO.fastq.gz
# [OK] ID_BJGGSH.mgb → ID_BJGGSH.fastq.gz
# [OK] ID_BJQEIQ.mgb → ID_BJQEIQ.fastq.gz
# [OK] ID_BJXLXW.mgb → ID_BJXLXW.fastq.gz
# [OK] ID_BKIANT.mgb → ID_BKIANT.fastq.gz
# [OK] ID_BKVWXN.mgb → ID_BKVWXN.fastq.gz
# [OK] ID_BKYBBG.mgb → ID_BKYBBG.fastq.gz
# [OK] ID_BLAFZC.mgb → ID_BLAFZC.fastq.gz
# [OK] ID_BLAIZT.mgb → ID_BLAIZT.fastq.gz
# [OK] ID_BLDEBH.mgb → ID_BLDEBH.fastq.gz
# [OK] ID_BLDNGS.mgb → ID_BLDNGS.fastq.gz
# [OK] ID_BLQETH.mgb → ID_BLQETH.fastq.gz
# [OK] ID_BLTYLD.mgb → ID_BLTYLD.fastq.gz
# [OK] ID_BMESXF.mgb → ID_BMESXF.fastq.gz
# [OK] ID_BMFRRV.mgb → ID_BMFRRV.fastq.gz
# [OK] ID_BMLKLW.mgb → ID_BMLKLW.fastq.gz
# [OK] ID_BMMZSJ.mgb → ID_BMMZSJ.fastq.gz
# [OK] ID_BMWGUY.mgb → ID_BMWGUY.fastq.gz
# [OK] ID_BMZNEJ.mgb → ID_BMZNEJ.fastq.gz
# [OK] ID_BNDJRR.mgb → ID_BNDJRR.fastq.gz
# [OK] ID_BNDVKB.mgb → ID_BNDVKB.fastq.gz
# [OK] ID_BNFDPZ.mgb → ID_BNFDPZ.fastq.gz
# [OK] ID_BNKLCS.mgb → ID_BNKLCS.fastq.gz
# [OK] ID_BNTGTO.mgb → ID_BNTGTO.fastq.gz
# [OK] ID_BOFMTL.mgb → ID_BOFMTL.fastq.gz
# [OK] ID_BOMJBA.mgb → ID_BOMJBA.fastq.gz
# [OK] ID_BOQBWG.mgb → ID_BOQBWG.fastq.gz
# [OK] ID_BORUEU.mgb → ID_BORUEU.fastq.gz
# [OK] ID_BOWURK.mgb → ID_BOWURK.fastq.gz
# [OK] ID_BPQBPM.mgb → ID_BPQBPM.fastq.gz
# [OK] ID_BPTILU.mgb → ID_BPTILU.fastq.gz
# [OK] ID_BPYARX.mgb → ID_BPYARX.fastq.gz
# [OK] ID_BQCEWH.mgb → ID_BQCEWH.fastq.gz
# [OK] ID_BQDHRK.mgb → ID_BQDHRK.fastq.gz
# [OK] ID_BQKGSR.mgb → ID_BQKGSR.fastq.gz
# [OK] ID_BQKLSM.mgb → ID_BQKLSM.fastq.gz
# [OK] ID_BQLRYY.mgb → ID_BQLRYY.fastq.gz
# [OK] ID_BQMYFD.mgb → ID_BQMYFD.fastq.gz
# [OK] ID_BQOEKK.mgb → ID_BQOEKK.fastq.gz
# [OK] ID_BQQKYL.mgb → ID_BQQKYL.fastq.gz
# [OK] ID_BQWBQQ.mgb → ID_BQWBQQ.fastq.gz
# [OK] ID_BQYGLN.mgb → ID_BQYGLN.fastq.gz
# [OK] ID_BRRBKW.mgb → ID_BRRBKW.fastq.gz
# [OK] ID_BRSWSX.mgb → ID_BRSWSX.fastq.gz
# [OK] ID_BSFQUS.mgb → ID_BSFQUS.fastq.gz
# [OK] ID_BSMPUS.mgb → ID_BSMPUS.fastq.gz
# [OK] ID_BSPPPF.mgb → ID_BSPPPF.fastq.gz
# [OK] ID_BSQXKA.mgb → ID_BSQXKA.fastq.gz
# [OK] ID_BSTIUS.mgb → ID_BSTIUS.fastq.gz
# [OK] ID_BSUHDL.mgb → ID_BSUHDL.fastq.gz
# [OK] ID_BTHMMQ.mgb → ID_BTHMMQ.fastq.gz
# [OK] ID_BTJTGC.mgb → ID_BTJTGC.fastq.gz
# [OK] ID_BTPNJQ.mgb → ID_BTPNJQ.fastq.gz
# [OK] ID_BUDNOC.mgb → ID_BUDNOC.fastq.gz
# [OK] ID_BUGOSE.mgb → ID_BUGOSE.fastq.gz
# [OK] ID_BUIREU.mgb → ID_BUIREU.fastq.gz
# [OK] ID_BUNZTA.mgb → ID_BUNZTA.fastq.gz
# [OK] ID_BUPXZV.mgb → ID_BUPXZV.fastq.gz
# [OK] ID_BUVRWB.mgb → ID_BUVRWB.fastq.gz
# [OK] ID_BVFLOS.mgb → ID_BVFLOS.fastq.gz
# [OK] ID_BVLVPJ.mgb → ID_BVLVPJ.fastq.gz
# [OK] ID_BVNPOC.mgb → ID_BVNPOC.fastq.gz
# [OK] ID_BVTAEF.mgb → ID_BVTAEF.fastq.gz
# [OK] ID_BVYIZG.mgb → ID_BVYIZG.fastq.gz
# [OK] ID_BWAYOW.mgb → ID_BWAYOW.fastq.gz
# [OK] ID_BWDIKA.mgb → ID_BWDIKA.fastq.gz
# [OK] ID_BWENZR.mgb → ID_BWENZR.fastq.gz
# [OK] ID_BWEZUZ.mgb → ID_BWEZUZ.fastq.gz
# [OK] ID_BWFRRW.mgb → ID_BWFRRW.fastq.gz
# [OK] ID_BWSTNB.mgb → ID_BWSTNB.fastq.gz
# [OK] ID_BWXHGA.mgb → ID_BWXHGA.fastq.gz
# [OK] ID_BXGOJU.mgb → ID_BXGOJU.fastq.gz
# [OK] ID_BXIDPN.mgb → ID_BXIDPN.fastq.gz
# [OK] ID_BXTZQR.mgb → ID_BXTZQR.fastq.gz
# [OK] ID_BXUISC.mgb → ID_BXUISC.fastq.gz
# [OK] ID_BXUSIL.mgb → ID_BXUSIL.fastq.gz
# [OK] ID_BXXAIZ.mgb → ID_BXXAIZ.fastq.gz
# [OK] ID_BXXFFI.mgb → ID_BXXFFI.fastq.gz
# [OK] ID_BYADQR.mgb → ID_BYADQR.fastq.gz
# [OK] ID_BYBBFU.mgb → ID_BYBBFU.fastq.gz
# [OK] ID_BYBDDN.mgb → ID_BYBDDN.fastq.gz
# [OK] ID_BYFKYS.mgb → ID_BYFKYS.fastq.gz
# [OK] ID_BYGTOX.mgb → ID_BYGTOX.fastq.gz
# [OK] ID_BYIDTS.mgb → ID_BYIDTS.fastq.gz
# [OK] ID_BYQAWV.mgb → ID_BYQAWV.fastq.gz
# [OK] ID_BYTILZ.mgb → ID_BYTILZ.fastq.gz
# [OK] ID_BYUSVC.mgb → ID_BYUSVC.fastq.gz
# [OK] ID_BYXUVL.mgb → ID_BYXUVL.fastq.gz
# [OK] ID_BZAEKX.mgb → ID_BZAEKX.fastq.gz
# [OK] ID_BZLNAL.mgb → ID_BZLNAL.fastq.gz
# [OK] ID_BZLYBW.mgb → ID_BZLYBW.fastq.gz
# [OK] ID_CABEZP.mgb → ID_CABEZP.fastq.gz
# [OK] ID_CAMZZK.mgb → ID_CAMZZK.fastq.gz
# [OK] ID_CAQGKS.mgb → ID_CAQGKS.fastq.gz
# [OK] ID_CAVMMY.mgb → ID_CAVMMY.fastq.gz
# [OK] ID_CBCIXT.mgb → ID_CBCIXT.fastq.gz
# [OK] ID_CBEPXX.mgb → ID_CBEPXX.fastq.gz
# [OK] ID_CBIXKY.mgb → ID_CBIXKY.fastq.gz
# [OK] ID_CBIYFC.mgb → ID_CBIYFC.fastq.gz
# [OK] ID_CBOALL.mgb → ID_CBOALL.fastq.gz
# [OK] ID_CBUHYF.mgb → ID_CBUHYF.fastq.gz
# [OK] ID_CBVUCG.mgb → ID_CBVUCG.fastq.gz
# [OK] ID_CBVZUG.mgb → ID_CBVZUG.fastq.gz
# [OK] ID_CBYCRL.mgb → ID_CBYCRL.fastq.gz
# [OK] ID_CCJFJF.mgb → ID_CCJFJF.fastq.gz
# [OK] ID_CCMXHQ.mgb → ID_CCMXHQ.fastq.gz
# [OK] ID_CCUWGC.mgb → ID_CCUWGC.fastq.gz
# [OK] ID_CCXOJL.mgb → ID_CCXOJL.fastq.gz
# [OK] ID_CCZQYA.mgb → ID_CCZQYA.fastq.gz
# [OK] ID_CDBSEY.mgb → ID_CDBSEY.fastq.gz
# [OK] ID_CDDJVZ.mgb → ID_CDDJVZ.fastq.gz
# [OK] ID_CDUQDF.mgb → ID_CDUQDF.fastq.gz
# [OK] ID_CEFEDI.mgb → ID_CEFEDI.fastq.gz
# [OK] ID_CEFFHZ.mgb → ID_CEFFHZ.fastq.gz
# [OK] ID_CEFQDN.mgb → ID_CEFQDN.fastq.gz
# [OK] ID_CEPVCX.mgb → ID_CEPVCX.fastq.gz
# [OK] ID_CFFBOX.mgb → ID_CFFBOX.fastq.gz
# [OK] ID_CFKXGH.mgb → ID_CFKXGH.fastq.gz
# [OK] ID_CFNKVZ.mgb → ID_CFNKVZ.fastq.gz
# [OK] ID_CFOWCA.mgb → ID_CFOWCA.fastq.gz
# [OK] ID_CGISFP.mgb → ID_CGISFP.fastq.gz
# [OK] ID_CGJOKG.mgb → ID_CGJOKG.fastq.gz
# [OK] ID_CHATBB.mgb → ID_CHATBB.fastq.gz
# [OK] ID_CHBZIR.mgb → ID_CHBZIR.fastq.gz
# [OK] ID_CHKMMC.mgb → ID_CHKMMC.fastq.gz
# [OK] ID_CHMRCZ.mgb → ID_CHMRCZ.fastq.gz
# [OK] ID_CHYNLQ.mgb → ID_CHYNLQ.fastq.gz
# [OK] ID_CIFVFZ.mgb → ID_CIFVFZ.fastq.gz
# [OK] ID_CISUFU.mgb → ID_CISUFU.fastq.gz
# [OK] ID_CIVZBZ.mgb → ID_CIVZBZ.fastq.gz
# [OK] ID_CIYRXW.mgb → ID_CIYRXW.fastq.gz
# [OK] ID_CJKSZF.mgb → ID_CJKSZF.fastq.gz
# [OK] ID_CJLWBX.mgb → ID_CJLWBX.fastq.gz
# [OK] ID_CJMARD.mgb → ID_CJMARD.fastq.gz
# [OK] ID_CJUUTB.mgb → ID_CJUUTB.fastq.gz
# [OK] ID_CJWDSQ.mgb → ID_CJWDSQ.fastq.gz
# [OK] ID_CKARPR.mgb → ID_CKARPR.fastq.gz
# [OK] ID_CKFMXI.mgb → ID_CKFMXI.fastq.gz
# [OK] ID_CKMDIW.mgb → ID_CKMDIW.fastq.gz
# [OK] ID_CKPEXK.mgb → ID_CKPEXK.fastq.gz
# [OK] ID_CKVZNG.mgb → ID_CKVZNG.fastq.gz
# [OK] ID_CLAMQX.mgb → ID_CLAMQX.fastq.gz
# [OK] ID_CLJFLL.mgb → ID_CLJFLL.fastq.gz
# [OK] ID_CLXVDF.mgb → ID_CLXVDF.fastq.gz
# [OK] ID_CMAJGS.mgb → ID_CMAJGS.fastq.gz
# [OK] ID_CMEXUB.mgb → ID_CMEXUB.fastq.gz
# [OK] ID_CMHVQS.mgb → ID_CMHVQS.fastq.gz
# [OK] ID_CMPEQT.mgb → ID_CMPEQT.fastq.gz
# [OK] ID_CMQPHP.mgb → ID_CMQPHP.fastq.gz
# [OK] ID_CMZCYC.mgb → ID_CMZCYC.fastq.gz
# [OK] ID_CNBDFU.mgb → ID_CNBDFU.fastq.gz
# [OK] ID_CNBVOC.mgb → ID_CNBVOC.fastq.gz
# [OK] ID_CNFRRA.mgb → ID_CNFRRA.fastq.gz
# [OK] ID_CNIPZX.mgb → ID_CNIPZX.fastq.gz
# [OK] ID_CNRAEX.mgb → ID_CNRAEX.fastq.gz
# [OK] ID_CNUXSO.mgb → ID_CNUXSO.fastq.gz
# [OK] ID_COFTSP.mgb → ID_COFTSP.fastq.gz
# [OK] ID_COGRXF.mgb → ID_COGRXF.fastq.gz
# [OK] ID_COGUSW.mgb → ID_COGUSW.fastq.gz
# [OK] ID_COLRYN.mgb → ID_COLRYN.fastq.gz
# [OK] ID_COMEWW.mgb → ID_COMEWW.fastq.gz
# [OK] ID_COPUFE.mgb → ID_COPUFE.fastq.gz
# [OK] ID_CPEYLN.mgb → ID_CPEYLN.fastq.gz
# [OK] ID_CQAKXN.mgb → ID_CQAKXN.fastq.gz
# [OK] ID_CQGPNK.mgb → ID_CQGPNK.fastq.gz
# [OK] ID_CQIRAJ.mgb → ID_CQIRAJ.fastq.gz
# [OK] ID_CQPPQL.mgb → ID_CQPPQL.fastq.gz
# [OK] ID_CRLCEG.mgb → ID_CRLCEG.fastq.gz
# [OK] ID_CRPLCW.mgb → ID_CRPLCW.fastq.gz
# [OK] ID_CSAQPN.mgb → ID_CSAQPN.fastq.gz
# [OK] ID_CSAWAL.mgb → ID_CSAWAL.fastq.gz
# [OK] ID_CSQMZL.mgb → ID_CSQMZL.fastq.gz
# [OK] ID_CSZLSG.mgb → ID_CSZLSG.fastq.gz
# [OK] ID_CTKKXZ.mgb → ID_CTKKXZ.fastq.gz
# [OK] ID_CTLUJH.mgb → ID_CTLUJH.fastq.gz
# [OK] ID_CUGOSP.mgb → ID_CUGOSP.fastq.gz
# [OK] ID_CUVJEW.mgb → ID_CUVJEW.fastq.gz
# [OK] ID_CVDANI.mgb → ID_CVDANI.fastq.gz
# [OK] ID_CVDRQB.mgb → ID_CVDRQB.fastq.gz
# [OK] ID_CVQKFR.mgb → ID_CVQKFR.fastq.gz
# [OK] ID_CVRNPA.mgb → ID_CVRNPA.fastq.gz
# [OK] ID_CVRRWM.mgb → ID_CVRRWM.fastq.gz
# [OK] ID_CVSQAL.mgb → ID_CVSQAL.fastq.gz
# [OK] ID_CVTKBV.mgb → ID_CVTKBV.fastq.gz
# [OK] ID_CVXTAJ.mgb → ID_CVXTAJ.fastq.gz
# [OK] ID_CWEFRZ.mgb → ID_CWEFRZ.fastq.gz
# [OK] ID_CWGLPS.mgb → ID_CWGLPS.fastq.gz
# [OK] ID_CWJNMW.mgb → ID_CWJNMW.fastq.gz
# [OK] ID_CWWHCQ.mgb → ID_CWWHCQ.fastq.gz
# [OK] ID_CXFQBO.mgb → ID_CXFQBO.fastq.gz
# [OK] ID_CYCFNA.mgb → ID_CYCFNA.fastq.gz
# [OK] ID_CYJYTY.mgb → ID_CYJYTY.fastq.gz
# [OK] ID_CYXSBU.mgb → ID_CYXSBU.fastq.gz
# [OK] ID_CYXSXV.mgb → ID_CYXSXV.fastq.gz
# [OK] ID_CZCTXV.mgb → ID_CZCTXV.fastq.gz
# [OK] ID_CZREPA.mgb → ID_CZREPA.fastq.gz
# [OK] ID_CZWYAC.mgb → ID_CZWYAC.fastq.gz
# [OK] ID_CZZDZW.mgb → ID_CZZDZW.fastq.gz
# [OK] ID_DAAZPM.mgb → ID_DAAZPM.fastq.gz
# [OK] ID_DABEIU.mgb → ID_DABEIU.fastq.gz
# [OK] ID_DACVKF.mgb → ID_DACVKF.fastq.gz
# [OK] ID_DAHWLQ.mgb → ID_DAHWLQ.fastq.gz
# [OK] ID_DAIMPD.mgb → ID_DAIMPD.fastq.gz
# [OK] ID_DBMDRE.mgb → ID_DBMDRE.fastq.gz
# [OK] ID_DBONRH.mgb → ID_DBONRH.fastq.gz
# [OK] ID_DBORVZ.mgb → ID_DBORVZ.fastq.gz
# [OK] ID_DBRZSV.mgb → ID_DBRZSV.fastq.gz
# [OK] ID_DBTOZR.mgb → ID_DBTOZR.fastq.gz
# [OK] ID_DCPNAQ.mgb → ID_DCPNAQ.fastq.gz
# [OK] ID_DCSGGY.mgb → ID_DCSGGY.fastq.gz
# [OK] ID_DCXMIR.mgb → ID_DCXMIR.fastq.gz
# [OK] ID_DCYFGD.mgb → ID_DCYFGD.fastq.gz
# [OK] ID_DCZLYK.mgb → ID_DCZLYK.fastq.gz
# [OK] ID_DCZWEX.mgb → ID_DCZWEX.fastq.gz
# [OK] ID_DDAAKL.mgb → ID_DDAAKL.fastq.gz
# [OK] ID_DDBXLW.mgb → ID_DDBXLW.fastq.gz
# [OK] ID_DDEORS.mgb → ID_DDEORS.fastq.gz
# [OK] ID_DDFSGU.mgb → ID_DDFSGU.fastq.gz
# [OK] ID_DDHTGO.mgb → ID_DDHTGO.fastq.gz
# [OK] ID_DDPTVX.mgb → ID_DDPTVX.fastq.gz
# [OK] ID_DDXNFC.mgb → ID_DDXNFC.fastq.gz
# [OK] ID_DEEOPS.mgb → ID_DEEOPS.fastq.gz
# [OK] ID_DEHQPX.mgb → ID_DEHQPX.fastq.gz
# [OK] ID_DEPLTQ.mgb → ID_DEPLTQ.fastq.gz
# [OK] ID_DEXQHR.mgb → ID_DEXQHR.fastq.gz
# [OK] ID_DFAUOS.mgb → ID_DFAUOS.fastq.gz
# [OK] ID_DFINMT.mgb → ID_DFINMT.fastq.gz
# [OK] ID_DFRYTE.mgb → ID_DFRYTE.fastq.gz
# [OK] ID_DGBPRY.mgb → ID_DGBPRY.fastq.gz
# [OK] ID_DGFBWI.mgb → ID_DGFBWI.fastq.gz
# [OK] ID_DGGQCW.mgb → ID_DGGQCW.fastq.gz
# [OK] ID_DGVTSK.mgb → ID_DGVTSK.fastq.gz
# [OK] ID_DGYWSB.mgb → ID_DGYWSB.fastq.gz
# [OK] ID_DHJYME.mgb → ID_DHJYME.fastq.gz
# [OK] ID_DHKWTO.mgb → ID_DHKWTO.fastq.gz
# [OK] ID_DHOGEM.mgb → ID_DHOGEM.fastq.gz
# [OK] ID_DHSUVH.mgb → ID_DHSUVH.fastq.gz
# [OK] ID_DIGQNV.mgb → ID_DIGQNV.fastq.gz
# [OK] ID_DIQPCS.mgb → ID_DIQPCS.fastq.gz
# [OK] ID_DITEVC.mgb → ID_DITEVC.fastq.gz
# [OK] ID_DIXWKV.mgb → ID_DIXWKV.fastq.gz
# [OK] ID_DJVEGJ.mgb → ID_DJVEGJ.fastq.gz
# [OK] ID_DJYPZW.mgb → ID_DJYPZW.fastq.gz
# [OK] ID_DJZTZA.mgb → ID_DJZTZA.fastq.gz
# [OK] ID_DKDBIW.mgb → ID_DKDBIW.fastq.gz
# [OK] ID_DKNVUZ.mgb → ID_DKNVUZ.fastq.gz
# [OK] ID_DKPBNN.mgb → ID_DKPBNN.fastq.gz
# [OK] ID_DKXOVC.mgb → ID_DKXOVC.fastq.gz
# [OK] ID_DLVVCV.mgb → ID_DLVVCV.fastq.gz
# [OK] ID_DMNCTG.mgb → ID_DMNCTG.fastq.gz
# [OK] ID_DMSFGF.mgb → ID_DMSFGF.fastq.gz
# [OK] ID_DMYPOS.mgb → ID_DMYPOS.fastq.gz
# [OK] ID_DMZRLF.mgb → ID_DMZRLF.fastq.gz
# [OK] ID_DNJJLA.mgb → ID_DNJJLA.fastq.gz
# [OK] ID_DNNPWN.mgb → ID_DNNPWN.fastq.gz
# [OK] ID_DNTCNB.mgb → ID_DNTCNB.fastq.gz
# [OK] ID_DNWBTT.mgb → ID_DNWBTT.fastq.gz
# [OK] ID_DOCYNQ.mgb → ID_DOCYNQ.fastq.gz
# [OK] ID_DOFZPC.mgb → ID_DOFZPC.fastq.gz
# [OK] ID_DOHOKN.mgb → ID_DOHOKN.fastq.gz
# [OK] ID_DPDRLS.mgb → ID_DPDRLS.fastq.gz
# [OK] ID_DPEDNC.mgb → ID_DPEDNC.fastq.gz
# [OK] ID_DPIFHP.mgb → ID_DPIFHP.fastq.gz
# [OK] ID_DPZTFG.mgb → ID_DPZTFG.fastq.gz
# [OK] ID_DQELDP.mgb → ID_DQELDP.fastq.gz
# [OK] ID_DQHVGC.mgb → ID_DQHVGC.fastq.gz
# [OK] ID_DQJJQJ.mgb → ID_DQJJQJ.fastq.gz
# [OK] ID_DQKZXE.mgb → ID_DQKZXE.fastq.gz
# [OK] ID_DQSGRS.mgb → ID_DQSGRS.fastq.gz
# [OK] ID_DQSUYJ.mgb → ID_DQSUYJ.fastq.gz
# [OK] ID_DRFAMX.mgb → ID_DRFAMX.fastq.gz
# [OK] ID_DRJQHV.mgb → ID_DRJQHV.fastq.gz
# [OK] ID_DRNQWD.mgb → ID_DRNQWD.fastq.gz
# [OK] ID_DRRMAD.mgb → ID_DRRMAD.fastq.gz
# [OK] ID_DRXXEF.mgb → ID_DRXXEF.fastq.gz
# [OK] ID_DSAWAB.mgb → ID_DSAWAB.fastq.gz
# [OK] ID_DSRASP.mgb → ID_DSRASP.fastq.gz
# [OK] ID_DSUENO.mgb → ID_DSUENO.fastq.gz
# [OK] ID_DSVELY.mgb → ID_DSVELY.fastq.gz
# [OK] ID_DTCCPX.mgb → ID_DTCCPX.fastq.gz
# [OK] ID_DUFHFT.mgb → ID_DUFHFT.fastq.gz
# [OK] ID_DUNUDO.mgb → ID_DUNUDO.fastq.gz
# [OK] ID_DVJULK.mgb → ID_DVJULK.fastq.gz
# [OK] ID_DVMUNS.mgb → ID_DVMUNS.fastq.gz
# [OK] ID_DVRMHL.mgb → ID_DVRMHL.fastq.gz
# [OK] ID_DVSPLI.mgb → ID_DVSPLI.fastq.gz
# [OK] ID_DVVFPM.mgb → ID_DVVFPM.fastq.gz
# [OK] ID_DWGIVD.mgb → ID_DWGIVD.fastq.gz
# [OK] ID_DWGTMB.mgb → ID_DWGTMB.fastq.gz
# [OK] ID_DWOULV.mgb → ID_DWOULV.fastq.gz
# [OK] ID_DWQKNK.mgb → ID_DWQKNK.fastq.gz
# [OK] ID_DWSEHL.mgb → ID_DWSEHL.fastq.gz
# [OK] ID_DWTNBS.mgb → ID_DWTNBS.fastq.gz
# [OK] ID_DWVFXS.mgb → ID_DWVFXS.fastq.gz
# [OK] ID_DXAHRJ.mgb → ID_DXAHRJ.fastq.gz
# [OK] ID_DXEKKM.mgb → ID_DXEKKM.fastq.gz
# [OK] ID_DXGSNJ.mgb → ID_DXGSNJ.fastq.gz
# [OK] ID_DXLBDU.mgb → ID_DXLBDU.fastq.gz
# [OK] ID_DXQFHN.mgb → ID_DXQFHN.fastq.gz
# [OK] ID_DXXDPY.mgb → ID_DXXDPY.fastq.gz
# [OK] ID_DXXSBN.mgb → ID_DXXSBN.fastq.gz
# [OK] ID_DYJVMA.mgb → ID_DYJVMA.fastq.gz
# [OK] ID_DYOJPK.mgb → ID_DYOJPK.fastq.gz
# [OK] ID_DYRSAU.mgb → ID_DYRSAU.fastq.gz
# [OK] ID_DZBRQT.mgb → ID_DZBRQT.fastq.gz
# [OK] ID_DZQLHM.mgb → ID_DZQLHM.fastq.gz
# [OK] ID_EAHSDZ.mgb → ID_EAHSDZ.fastq.gz
# [OK] ID_EALMKI.mgb → ID_EALMKI.fastq.gz
# [OK] ID_EAMLGJ.mgb → ID_EAMLGJ.fastq.gz
# [OK] ID_EASEGB.mgb → ID_EASEGB.fastq.gz
# [OK] ID_EAUUBU.mgb → ID_EAUUBU.fastq.gz
# [OK] ID_EAYVHY.mgb → ID_EAYVHY.fastq.gz
# [OK] ID_EAZIWC.mgb → ID_EAZIWC.fastq.gz
# [OK] ID_EBHRVE.mgb → ID_EBHRVE.fastq.gz
# [OK] ID_EBHXEE.mgb → ID_EBHXEE.fastq.gz
# [OK] ID_EBJBKI.mgb → ID_EBJBKI.fastq.gz
# [OK] ID_EBMDBW.mgb → ID_EBMDBW.fastq.gz
# [OK] ID_EBXBLO.mgb → ID_EBXBLO.fastq.gz
# [OK] ID_EBXZDT.mgb → ID_EBXZDT.fastq.gz
# [OK] ID_ECCGCP.mgb → ID_ECCGCP.fastq.gz
# [OK] ID_ECEDQO.mgb → ID_ECEDQO.fastq.gz
# [OK] ID_ECXCYD.mgb → ID_ECXCYD.fastq.gz
# [OK] ID_EDJGWX.mgb → ID_EDJGWX.fastq.gz
# [OK] ID_EDRXXQ.mgb → ID_EDRXXQ.fastq.gz
# [OK] ID_EDSZLU.mgb → ID_EDSZLU.fastq.gz
# [OK] ID_EDYHRU.mgb → ID_EDYHRU.fastq.gz
# [OK] ID_EEBJLN.mgb → ID_EEBJLN.fastq.gz
# [OK] ID_EEEMQC.mgb → ID_EEEMQC.fastq.gz
# [OK] ID_EEYIEW.mgb → ID_EEYIEW.fastq.gz
# [OK] ID_EFHTFR.mgb → ID_EFHTFR.fastq.gz
# [OK] ID_EFIXCE.mgb → ID_EFIXCE.fastq.gz
# [OK] ID_EFPRGI.mgb → ID_EFPRGI.fastq.gz
# [OK] ID_EGAWZG.mgb → ID_EGAWZG.fastq.gz
# [OK] ID_EGDJKU.mgb → ID_EGDJKU.fastq.gz
# [OK] ID_EGGOJH.mgb → ID_EGGOJH.fastq.gz
# [OK] ID_EGXKRV.mgb → ID_EGXKRV.fastq.gz
# [OK] ID_EHCCXF.mgb → ID_EHCCXF.fastq.gz
# [OK] ID_EHJADX.mgb → ID_EHJADX.fastq.gz
# [OK] ID_EHLHXH.mgb → ID_EHLHXH.fastq.gz
# [OK] ID_EHQWZN.mgb → ID_EHQWZN.fastq.gz
# [OK] ID_EHUOAV.mgb → ID_EHUOAV.fastq.gz
# [OK] ID_EHZHQM.mgb → ID_EHZHQM.fastq.gz
# [OK] ID_EICCAN.mgb → ID_EICCAN.fastq.gz
# [OK] ID_EIHMGE.mgb → ID_EIHMGE.fastq.gz
# [OK] ID_EIOCOK.mgb → ID_EIOCOK.fastq.gz
# [OK] ID_EJCWGM.mgb → ID_EJCWGM.fastq.gz
# [OK] ID_EJFEWM.mgb → ID_EJFEWM.fastq.gz
# [OK] ID_EJINYE.mgb → ID_EJINYE.fastq.gz
# [OK] ID_EJMLOW.mgb → ID_EJMLOW.fastq.gz
# [OK] ID_EJVYKU.mgb → ID_EJVYKU.fastq.gz
# [OK] ID_EKFEBW.mgb → ID_EKFEBW.fastq.gz
# [OK] ID_EKGEQY.mgb → ID_EKGEQY.fastq.gz
# [OK] ID_EKLDLL.mgb → ID_EKLDLL.fastq.gz
# [OK] ID_EKMOCN.mgb → ID_EKMOCN.fastq.gz
# [OK] ID_EKMYAN.mgb → ID_EKMYAN.fastq.gz
# [OK] ID_EKNQHF.mgb → ID_EKNQHF.fastq.gz
# [OK] ID_EKQQNR.mgb → ID_EKQQNR.fastq.gz
# [OK] ID_EKWJKN.mgb → ID_EKWJKN.fastq.gz
# [OK] ID_ELUJSA.mgb → ID_ELUJSA.fastq.gz
# [OK] ID_ELUMYU.mgb → ID_ELUMYU.fastq.gz
# [OK] ID_EMDVPR.mgb → ID_EMDVPR.fastq.gz
# [OK] ID_EMEMQN.mgb → ID_EMEMQN.fastq.gz
# [OK] ID_EMPUET.mgb → ID_EMPUET.fastq.gz
# [OK] ID_EMXBST.mgb → ID_EMXBST.fastq.gz
# [OK] ID_ENPDII.mgb → ID_ENPDII.fastq.gz
# [OK] ID_ENTHMT.mgb → ID_ENTHMT.fastq.gz
# [OK] ID_EOEKFK.mgb → ID_EOEKFK.fastq.gz
# [OK] ID_EOFJYY.mgb → ID_EOFJYY.fastq.gz
# [OK] ID_EOPVWI.mgb → ID_EOPVWI.fastq.gz
# [OK] ID_EOTFRJ.mgb → ID_EOTFRJ.fastq.gz
# [OK] ID_EOYXMZ.mgb → ID_EOYXMZ.fastq.gz
# [OK] ID_EPFBJN.mgb → ID_EPFBJN.fastq.gz
# [OK] ID_EPFKPV.mgb → ID_EPFKPV.fastq.gz
# [OK] ID_EPHGWF.mgb → ID_EPHGWF.fastq.gz
# [OK] ID_EPHMFD.mgb → ID_EPHMFD.fastq.gz
# [OK] ID_EPOOYS.mgb → ID_EPOOYS.fastq.gz
# [OK] ID_EPQAGU.mgb → ID_EPQAGU.fastq.gz
# [OK] ID_EPTMKH.mgb → ID_EPTMKH.fastq.gz
# [OK] ID_EQTHRG.mgb → ID_EQTHRG.fastq.gz
# [OK] ID_EQUKGI.mgb → ID_EQUKGI.fastq.gz
# [OK] ID_ERBWJV.mgb → ID_ERBWJV.fastq.gz
# [OK] ID_ERGFRA.mgb → ID_ERGFRA.fastq.gz
# [OK] ID_ERWHVV.mgb → ID_ERWHVV.fastq.gz
# [OK] ID_ESAWNV.mgb → ID_ESAWNV.fastq.gz
# [OK] ID_ESDTLH.mgb → ID_ESDTLH.fastq.gz
# [OK] ID_ESODFA.mgb → ID_ESODFA.fastq.gz
# [OK] ID_ESUPOV.mgb → ID_ESUPOV.fastq.gz
# [OK] ID_ETHGVP.mgb → ID_ETHGVP.fastq.gz
# [OK] ID_ETQKXV.mgb → ID_ETQKXV.fastq.gz
# [OK] ID_ETRVTP.mgb → ID_ETRVTP.fastq.gz
# [OK] ID_ETXPIR.mgb → ID_ETXPIR.fastq.gz
# [OK] ID_EUFHUG.mgb → ID_EUFHUG.fastq.gz
# [OK] ID_EUINVA.mgb → ID_EUINVA.fastq.gz
# [OK] ID_EUZWPA.mgb → ID_EUZWPA.fastq.gz
# [OK] ID_EVBJJD.mgb → ID_EVBJJD.fastq.gz
# [OK] ID_EVJBEP.mgb → ID_EVJBEP.fastq.gz
# [OK] ID_EVLRBX.mgb → ID_EVLRBX.fastq.gz
# [OK] ID_EVMBHD.mgb → ID_EVMBHD.fastq.gz
# [OK] ID_EVMGGW.mgb → ID_EVMGGW.fastq.gz
# [OK] ID_EVURNP.mgb → ID_EVURNP.fastq.gz
# [OK] ID_EVZHVT.mgb → ID_EVZHVT.fastq.gz
# [OK] ID_EWCACQ.mgb → ID_EWCACQ.fastq.gz
# [OK] ID_EWUBBL.mgb → ID_EWUBBL.fastq.gz
# [OK] ID_EXAYPI.mgb → ID_EXAYPI.fastq.gz
# [OK] ID_EXBIGU.mgb → ID_EXBIGU.fastq.gz
# [OK] ID_EXIKXS.mgb → ID_EXIKXS.fastq.gz
# [OK] ID_EXJIWD.mgb → ID_EXJIWD.fastq.gz
# [OK] ID_EXLVYN.mgb → ID_EXLVYN.fastq.gz
# [OK] ID_EXQRCX.mgb → ID_EXQRCX.fastq.gz
# [OK] ID_EXRTZW.mgb → ID_EXRTZW.fastq.gz
# [OK] ID_EXUGFJ.mgb → ID_EXUGFJ.fastq.gz
# [OK] ID_EXVVJI.mgb → ID_EXVVJI.fastq.gz
# [OK] ID_EXWWFZ.mgb → ID_EXWWFZ.fastq.gz
# [OK] ID_EYORZK.mgb → ID_EYORZK.fastq.gz
# [OK] ID_EZJGYV.mgb → ID_EZJGYV.fastq.gz
# [OK] ID_EZLAQM.mgb → ID_EZLAQM.fastq.gz
# [OK] ID_FACXSQ.mgb → ID_FACXSQ.fastq.gz
# [OK] ID_FAJLFZ.mgb → ID_FAJLFZ.fastq.gz
# [OK] ID_FALCRY.mgb → ID_FALCRY.fastq.gz
# [OK] ID_FAURZL.mgb → ID_FAURZL.fastq.gz
# [OK] ID_FAWDJR.mgb → ID_FAWDJR.fastq.gz
# [OK] ID_FBBDXQ.mgb → ID_FBBDXQ.fastq.gz
# [OK] ID_FBCXIS.mgb → ID_FBCXIS.fastq.gz
# [OK] ID_FBKYYV.mgb → ID_FBKYYV.fastq.gz
# [OK] ID_FBSEEL.mgb → ID_FBSEEL.fastq.gz
# [OK] ID_FBTFFR.mgb → ID_FBTFFR.fastq.gz
# [OK] ID_FCKCUF.mgb → ID_FCKCUF.fastq.gz
# [OK] ID_FCYPUZ.mgb → ID_FCYPUZ.fastq.gz
# [OK] ID_FDBBJE.mgb → ID_FDBBJE.fastq.gz
# [OK] ID_FDDPOD.mgb → ID_FDDPOD.fastq.gz
# [OK] ID_FDWOOT.mgb → ID_FDWOOT.fastq.gz
# [OK] ID_FDXJMZ.mgb → ID_FDXJMZ.fastq.gz
# [OK] ID_FFDIVT.mgb → ID_FFDIVT.fastq.gz
# [OK] ID_FFUNFF.mgb → ID_FFUNFF.fastq.gz
# [OK] ID_FFYAYM.mgb → ID_FFYAYM.fastq.gz
# [OK] ID_FGGESJ.mgb → ID_FGGESJ.fastq.gz
# [OK] ID_FGTPVX.mgb → ID_FGTPVX.fastq.gz
# [OK] ID_FHCHZN.mgb → ID_FHCHZN.fastq.gz
# [OK] ID_FHMIDE.mgb → ID_FHMIDE.fastq.gz
# [OK] ID_FHRZTW.mgb → ID_FHRZTW.fastq.gz
# [OK] ID_FIJEGA.mgb → ID_FIJEGA.fastq.gz
# [OK] ID_FIJZDE.mgb → ID_FIJZDE.fastq.gz
# [OK] ID_FILPKR.mgb → ID_FILPKR.fastq.gz
# [OK] ID_FIPCHC.mgb → ID_FIPCHC.fastq.gz
# [OK] ID_FIWXCN.mgb → ID_FIWXCN.fastq.gz
# [OK] ID_FJTWHB.mgb → ID_FJTWHB.fastq.gz
# [OK] ID_FKCKXF.mgb → ID_FKCKXF.fastq.gz
# [OK] ID_FKTWPG.mgb → ID_FKTWPG.fastq.gz
# [OK] ID_FLDAYX.mgb → ID_FLDAYX.fastq.gz
# [OK] ID_FLIEXR.mgb → ID_FLIEXR.fastq.gz
# [OK] ID_FLJTST.mgb → ID_FLJTST.fastq.gz
# [OK] ID_FLKOMT.mgb → ID_FLKOMT.fastq.gz
# [OK] ID_FLQZLA.mgb → ID_FLQZLA.fastq.gz
# [OK] ID_FMMZCY.mgb → ID_FMMZCY.fastq.gz
# [OK] ID_FNHNKA.mgb → ID_FNHNKA.fastq.gz
# [OK] ID_FNJIVR.mgb → ID_FNJIVR.fastq.gz
# [OK] ID_FODWDJ.mgb → ID_FODWDJ.fastq.gz
# [OK] ID_FOVLKI.mgb → ID_FOVLKI.fastq.gz
# [OK] ID_FOWHZJ.mgb → ID_FOWHZJ.fastq.gz
# [OK] ID_FOZMYZ.mgb → ID_FOZMYZ.fastq.gz
# [OK] ID_FPEPUL.mgb → ID_FPEPUL.fastq.gz
# [OK] ID_FPGBOF.mgb → ID_FPGBOF.fastq.gz
# [OK] ID_FPKEDK.mgb → ID_FPKEDK.fastq.gz
# [OK] ID_FPKXTO.mgb → ID_FPKXTO.fastq.gz
# [OK] ID_FPLZRJ.mgb → ID_FPLZRJ.fastq.gz
# [OK] ID_FPQYYD.mgb → ID_FPQYYD.fastq.gz
# [OK] ID_FPRVSL.mgb → ID_FPRVSL.fastq.gz
# [OK] ID_FQCNAG.mgb → ID_FQCNAG.fastq.gz
# [OK] ID_FQKAOT.mgb → ID_FQKAOT.fastq.gz
# [OK] ID_FQMKVG.mgb → ID_FQMKVG.fastq.gz
# [OK] ID_FQMMSZ.mgb → ID_FQMMSZ.fastq.gz
# [OK] ID_FRCTZM.mgb → ID_FRCTZM.fastq.gz
# [OK] ID_FRDMPG.mgb → ID_FRDMPG.fastq.gz
# [OK] ID_FRKQVF.mgb → ID_FRKQVF.fastq.gz
# [OK] ID_FRMVYC.mgb → ID_FRMVYC.fastq.gz
# [OK] ID_FRUXFP.mgb → ID_FRUXFP.fastq.gz
# [OK] ID_FRXGFZ.mgb → ID_FRXGFZ.fastq.gz
# [OK] ID_FSODDQ.mgb → ID_FSODDQ.fastq.gz
# [OK] ID_FTEOTG.mgb → ID_FTEOTG.fastq.gz
# [OK] ID_FTQWVW.mgb → ID_FTQWVW.fastq.gz
# [OK] ID_FTVZGW.mgb → ID_FTVZGW.fastq.gz
# [OK] ID_FTXYTT.mgb → ID_FTXYTT.fastq.gz
# [OK] ID_FUFWJA.mgb → ID_FUFWJA.fastq.gz
# [OK] ID_FUJUAB.mgb → ID_FUJUAB.fastq.gz
# [OK] ID_FURIVI.mgb → ID_FURIVI.fastq.gz
# [OK] ID_FVAQXQ.mgb → ID_FVAQXQ.fastq.gz
# [OK] ID_FVBZVJ.mgb → ID_FVBZVJ.fastq.gz
# [OK] ID_FVLZPX.mgb → ID_FVLZPX.fastq.gz
# [OK] ID_FVPHLO.mgb → ID_FVPHLO.fastq.gz
# [OK] ID_FVTSHW.mgb → ID_FVTSHW.fastq.gz
# [OK] ID_FXAPFM.mgb → ID_FXAPFM.fastq.gz
# [OK] ID_FXNPNX.mgb → ID_FXNPNX.fastq.gz
# [OK] ID_FYCYZB.mgb → ID_FYCYZB.fastq.gz
# [OK] ID_FYSOSQ.mgb → ID_FYSOSQ.fastq.gz
# [OK] ID_FZCZKS.mgb → ID_FZCZKS.fastq.gz
# [OK] ID_FZDSHC.mgb → ID_FZDSHC.fastq.gz
# [OK] ID_FZPNCD.mgb → ID_FZPNCD.fastq.gz
# [OK] ID_GANOEF.mgb → ID_GANOEF.fastq.gz
# [OK] ID_GAXKVD.mgb → ID_GAXKVD.fastq.gz
# [OK] ID_GBAULY.mgb → ID_GBAULY.fastq.gz
# [OK] ID_GBCEJT.mgb → ID_GBCEJT.fastq.gz
# [OK] ID_GBDOVN.mgb → ID_GBDOVN.fastq.gz
# [OK] ID_GBMYXH.mgb → ID_GBMYXH.fastq.gz
# [OK] ID_GBPGVS.mgb → ID_GBPGVS.fastq.gz
# [OK] ID_GBRVVD.mgb → ID_GBRVVD.fastq.gz
# [OK] ID_GBUDSX.mgb → ID_GBUDSX.fastq.gz
# [OK] ID_GBYAJJ.mgb → ID_GBYAJJ.fastq.gz
# [OK] ID_GCFFAB.mgb → ID_GCFFAB.fastq.gz
# [OK] ID_GCMGNU.mgb → ID_GCMGNU.fastq.gz
# [OK] ID_GCNZIZ.mgb → ID_GCNZIZ.fastq.gz
# [OK] ID_GDNEOF.mgb → ID_GDNEOF.fastq.gz
# [OK] ID_GDTXBD.mgb → ID_GDTXBD.fastq.gz
# [OK] ID_GDVGDR.mgb → ID_GDVGDR.fastq.gz
# [OK] ID_GDVRGD.mgb → ID_GDVRGD.fastq.gz
# [OK] ID_GEELZK.mgb → ID_GEELZK.fastq.gz
# [OK] ID_GEFSWM.mgb → ID_GEFSWM.fastq.gz
# [OK] ID_GEMQTS.mgb → ID_GEMQTS.fastq.gz
# [OK] ID_GENDGZ.mgb → ID_GENDGZ.fastq.gz
# [OK] ID_GEOFWJ.mgb → ID_GEOFWJ.fastq.gz
# [OK] ID_GFCTSV.mgb → ID_GFCTSV.fastq.gz
# [OK] ID_GFFEEZ.mgb → ID_GFFEEZ.fastq.gz
# [OK] ID_GFHAUV.mgb → ID_GFHAUV.fastq.gz
# [OK] ID_GFIYUN.mgb → ID_GFIYUN.fastq.gz
# [OK] ID_GFNQFS.mgb → ID_GFNQFS.fastq.gz
# [OK] ID_GFRTWH.mgb → ID_GFRTWH.fastq.gz
# [OK] ID_GGJYBO.mgb → ID_GGJYBO.fastq.gz
# [OK] ID_GGKAQN.mgb → ID_GGKAQN.fastq.gz
# [OK] ID_GGKVWD.mgb → ID_GGKVWD.fastq.gz
# [OK] ID_GGMDFB.mgb → ID_GGMDFB.fastq.gz
# [OK] ID_GHJOKH.mgb → ID_GHJOKH.fastq.gz
# [OK] ID_GHSKAW.mgb → ID_GHSKAW.fastq.gz
# [OK] ID_GHXXTQ.mgb → ID_GHXXTQ.fastq.gz
# [OK] ID_GHZSUX.mgb → ID_GHZSUX.fastq.gz
# [OK] ID_GIAEFN.mgb → ID_GIAEFN.fastq.gz
# [OK] ID_GIEFMZ.mgb → ID_GIEFMZ.fastq.gz
# [OK] ID_GIKQEK.mgb → ID_GIKQEK.fastq.gz
# [OK] ID_GJABOO.mgb → ID_GJABOO.fastq.gz
# [OK] ID_GJFFMD.mgb → ID_GJFFMD.fastq.gz
# [OK] ID_GJHDZB.mgb → ID_GJHDZB.fastq.gz
# [OK] ID_GJKDOG.mgb → ID_GJKDOG.fastq.gz
# [OK] ID_GJOLAQ.mgb → ID_GJOLAQ.fastq.gz
# [OK] ID_GJSLWP.mgb → ID_GJSLWP.fastq.gz
# [OK] ID_GKDVXC.mgb → ID_GKDVXC.fastq.gz
# [OK] ID_GKTNPJ.mgb → ID_GKTNPJ.fastq.gz
# [OK] ID_GKZBPN.mgb → ID_GKZBPN.fastq.gz
# [OK] ID_GKZLFR.mgb → ID_GKZLFR.fastq.gz
# [OK] ID_GLLBAM.mgb → ID_GLLBAM.fastq.gz
# [OK] ID_GLNHIR.mgb → ID_GLNHIR.fastq.gz
# [OK] ID_GLOVLA.mgb → ID_GLOVLA.fastq.gz
# [OK] ID_GLOYZY.mgb → ID_GLOYZY.fastq.gz
# [OK] ID_GLRTON.mgb → ID_GLRTON.fastq.gz
# [OK] ID_GLSQXJ.mgb → ID_GLSQXJ.fastq.gz
# [OK] ID_GLSYPJ.mgb → ID_GLSYPJ.fastq.gz
# [OK] ID_GLTYBO.mgb → ID_GLTYBO.fastq.gz
# [OK] ID_GLWZXW.mgb → ID_GLWZXW.fastq.gz
# [OK] ID_GLXLFH.mgb → ID_GLXLFH.fastq.gz
# [OK] ID_GLYWSM.mgb → ID_GLYWSM.fastq.gz
# [OK] ID_GMGMCM.mgb → ID_GMGMCM.fastq.gz
# [OK] ID_GMKYOE.mgb → ID_GMKYOE.fastq.gz
# [OK] ID_GMSOCA.mgb → ID_GMSOCA.fastq.gz
# [OK] ID_GMZGPZ.mgb → ID_GMZGPZ.fastq.gz
# [OK] ID_GNBMER.mgb → ID_GNBMER.fastq.gz
# [OK] ID_GNEGGC.mgb → ID_GNEGGC.fastq.gz
# [OK] ID_GNJTKB.mgb → ID_GNJTKB.fastq.gz
# [OK] ID_GNNAYG.mgb → ID_GNNAYG.fastq.gz
# [OK] ID_GNQNDQ.mgb → ID_GNQNDQ.fastq.gz
# [OK] ID_GOFXGR.mgb → ID_GOFXGR.fastq.gz
# [OK] ID_GOLUJM.mgb → ID_GOLUJM.fastq.gz
# [OK] ID_GOQMDD.mgb → ID_GOQMDD.fastq.gz
# [OK] ID_GPGORL.mgb → ID_GPGORL.fastq.gz
# [OK] ID_GPHOZN.mgb → ID_GPHOZN.fastq.gz
# [OK] ID_GPLRPT.mgb → ID_GPLRPT.fastq.gz
# [OK] ID_GPPTXJ.mgb → ID_GPPTXJ.fastq.gz
# [OK] ID_GPQZKC.mgb → ID_GPQZKC.fastq.gz
# [OK] ID_GPTSEY.mgb → ID_GPTSEY.fastq.gz
# [OK] ID_GQCQHX.mgb → ID_GQCQHX.fastq.gz
# [OK] ID_GQJLQY.mgb → ID_GQJLQY.fastq.gz
# [OK] ID_GQQMCG.mgb → ID_GQQMCG.fastq.gz
# [OK] ID_GQUWWD.mgb → ID_GQUWWD.fastq.gz
# [OK] ID_GQWHHI.mgb → ID_GQWHHI.fastq.gz
# [OK] ID_GRCEUB.mgb → ID_GRCEUB.fastq.gz
# [OK] ID_GRCXCP.mgb → ID_GRCXCP.fastq.gz
# [OK] ID_GRHMZM.mgb → ID_GRHMZM.fastq.gz
# [OK] ID_GRJMQZ.mgb → ID_GRJMQZ.fastq.gz
# [OK] ID_GRKDCW.mgb → ID_GRKDCW.fastq.gz
# [OK] ID_GRPRTP.mgb → ID_GRPRTP.fastq.gz
# [OK] ID_GRTICK.mgb → ID_GRTICK.fastq.gz
# [OK] ID_GRTYYR.mgb → ID_GRTYYR.fastq.gz
# [OK] ID_GSALDD.mgb → ID_GSALDD.fastq.gz
# [OK] ID_GSCJSM.mgb → ID_GSCJSM.fastq.gz
# [OK] ID_GSNSGC.mgb → ID_GSNSGC.fastq.gz
# [OK] ID_GSQONH.mgb → ID_GSQONH.fastq.gz
# [OK] ID_GTABTQ.mgb → ID_GTABTQ.fastq.gz
# [OK] ID_GTAGPT.mgb → ID_GTAGPT.fastq.gz
# [OK] ID_GTDNKH.mgb → ID_GTDNKH.fastq.gz
# [OK] ID_GTXZUE.mgb → ID_GTXZUE.fastq.gz
# [OK] ID_GTYIOV.mgb → ID_GTYIOV.fastq.gz
# [OK] ID_GUIAEM.mgb → ID_GUIAEM.fastq.gz
# [OK] ID_GUUFXF.mgb → ID_GUUFXF.fastq.gz
# [OK] ID_GUUGQU.mgb → ID_GUUGQU.fastq.gz
# [OK] ID_GUYVRA.mgb → ID_GUYVRA.fastq.gz
# [OK] ID_GVCXOP.mgb → ID_GVCXOP.fastq.gz
# [OK] ID_GVOZYJ.mgb → ID_GVOZYJ.fastq.gz
# [OK] ID_GVVWFW.mgb → ID_GVVWFW.fastq.gz
# [OK] ID_GVXRZM.mgb → ID_GVXRZM.fastq.gz
# [OK] ID_GWHUEE.mgb → ID_GWHUEE.fastq.gz
# [OK] ID_GWIGBZ.mgb → ID_GWIGBZ.fastq.gz
# [OK] ID_GWJGSH.mgb → ID_GWJGSH.fastq.gz
# [OK] ID_GWTGNL.mgb → ID_GWTGNL.fastq.gz
# [OK] ID_GWVMNU.mgb → ID_GWVMNU.fastq.gz
# [OK] ID_GWZOWW.mgb → ID_GWZOWW.fastq.gz
# [OK] ID_GXFSWH.mgb → ID_GXFSWH.fastq.gz
# [OK] ID_GXHXNA.mgb → ID_GXHXNA.fastq.gz
# [OK] ID_GXIPLD.mgb → ID_GXIPLD.fastq.gz
# [OK] ID_GXNGNI.mgb → ID_GXNGNI.fastq.gz
# [OK] ID_GXOSOK.mgb → ID_GXOSOK.fastq.gz
# [OK] ID_GXSLAN.mgb → ID_GXSLAN.fastq.gz
# [OK] ID_GXYTEI.mgb → ID_GXYTEI.fastq.gz
# [OK] ID_GYHCOB.mgb → ID_GYHCOB.fastq.gz
# [OK] ID_GYJTAK.mgb → ID_GYJTAK.fastq.gz
# [OK] ID_GYMHEV.mgb → ID_GYMHEV.fastq.gz
# [OK] ID_GYMSWN.mgb → ID_GYMSWN.fastq.gz
# [OK] ID_GYRUNP.mgb → ID_GYRUNP.fastq.gz
# [OK] ID_GYXHSK.mgb → ID_GYXHSK.fastq.gz
# [OK] ID_GZADEM.mgb → ID_GZADEM.fastq.gz
# [OK] ID_GZBKOS.mgb → ID_GZBKOS.fastq.gz
# [OK] ID_GZGIZP.mgb → ID_GZGIZP.fastq.gz
# [OK] ID_GZTFLD.mgb → ID_GZTFLD.fastq.gz
# [OK] ID_HAFLSR.mgb → ID_HAFLSR.fastq.gz
# [OK] ID_HAIJLH.mgb → ID_HAIJLH.fastq.gz
# [OK] ID_HAIJZQ.mgb → ID_HAIJZQ.fastq.gz
# [OK] ID_HAJEAO.mgb → ID_HAJEAO.fastq.gz
# [OK] ID_HAKKHZ.mgb → ID_HAKKHZ.fastq.gz
# [OK] ID_HAMDMS.mgb → ID_HAMDMS.fastq.gz
# [OK] ID_HAMZVO.mgb → ID_HAMZVO.fastq.gz
# [OK] ID_HBDGLE.mgb → ID_HBDGLE.fastq.gz
# [OK] ID_HBETBW.mgb → ID_HBETBW.fastq.gz
# [OK] ID_HBKNBS.mgb → ID_HBKNBS.fastq.gz
# [OK] ID_HBPQDJ.mgb → ID_HBPQDJ.fastq.gz
# [OK] ID_HBVOUD.mgb → ID_HBVOUD.fastq.gz
# [OK] ID_HBWDIW.mgb → ID_HBWDIW.fastq.gz
# [OK] ID_HCCCBB.mgb → ID_HCCCBB.fastq.gz
# [OK] ID_HCFEMZ.mgb → ID_HCFEMZ.fastq.gz
# [OK] ID_HCIQHB.mgb → ID_HCIQHB.fastq.gz
# [OK] ID_HCLZSD.mgb → ID_HCLZSD.fastq.gz
# [OK] ID_HCTDDM.mgb → ID_HCTDDM.fastq.gz
# [OK] ID_HCUPTU.mgb → ID_HCUPTU.fastq.gz
# [OK] ID_HCXNEC.mgb → ID_HCXNEC.fastq.gz
# [OK] ID_HDASYN.mgb → ID_HDASYN.fastq.gz
# [OK] ID_HDUNQW.mgb → ID_HDUNQW.fastq.gz
# [OK] ID_HDWBVN.mgb → ID_HDWBVN.fastq.gz
# [OK] ID_HDWWRU.mgb → ID_HDWWRU.fastq.gz
# [OK] ID_HDZEGY.mgb → ID_HDZEGY.fastq.gz
# [OK] ID_HEFQVW.mgb → ID_HEFQVW.fastq.gz
# [OK] ID_HEHLPI.mgb → ID_HEHLPI.fastq.gz
# [OK] ID_HEWIFO.mgb → ID_HEWIFO.fastq.gz
# [OK] ID_HFCWLM.mgb → ID_HFCWLM.fastq.gz
# [OK] ID_HFEBDE.mgb → ID_HFEBDE.fastq.gz
# [OK] ID_HFJWIF.mgb → ID_HFJWIF.fastq.gz
# [OK] ID_HFQBSF.mgb → ID_HFQBSF.fastq.gz
# [OK] ID_HFRXAS.mgb → ID_HFRXAS.fastq.gz
# [OK] ID_HGDOYR.mgb → ID_HGDOYR.fastq.gz
# [OK] ID_HGHCBS.mgb → ID_HGHCBS.fastq.gz
# [OK] ID_HGLZKW.mgb → ID_HGLZKW.fastq.gz
# [OK] ID_HGVJGT.mgb → ID_HGVJGT.fastq.gz
# [OK] ID_HGWWCC.mgb → ID_HGWWCC.fastq.gz
# [OK] ID_HHCDRO.mgb → ID_HHCDRO.fastq.gz
# [OK] ID_HHEEJO.mgb → ID_HHEEJO.fastq.gz
# [OK] ID_HHHEOZ.mgb → ID_HHHEOZ.fastq.gz
# [OK] ID_HHKPJY.mgb → ID_HHKPJY.fastq.gz
# [OK] ID_HIJCEV.mgb → ID_HIJCEV.fastq.gz
# [OK] ID_HIJLOO.mgb → ID_HIJLOO.fastq.gz
# [OK] ID_HIKCHL.mgb → ID_HIKCHL.fastq.gz
# [OK] ID_HIMTUO.mgb → ID_HIMTUO.fastq.gz
# [OK] ID_HIYBTP.mgb → ID_HIYBTP.fastq.gz
# [OK] ID_HJKPUK.mgb → ID_HJKPUK.fastq.gz
# [OK] ID_HJQFVZ.mgb → ID_HJQFVZ.fastq.gz
# [OK] ID_HJVKCU.mgb → ID_HJVKCU.fastq.gz
# [OK] ID_HKBOLI.mgb → ID_HKBOLI.fastq.gz
# [OK] ID_HKIYYZ.mgb → ID_HKIYYZ.fastq.gz
# [OK] ID_HKRRVK.mgb → ID_HKRRVK.fastq.gz
# [OK] ID_HKUBZK.mgb → ID_HKUBZK.fastq.gz
# [OK] ID_HLDYOR.mgb → ID_HLDYOR.fastq.gz
# [OK] ID_HLTHTK.mgb → ID_HLTHTK.fastq.gz
# [OK] ID_HLWTFS.mgb → ID_HLWTFS.fastq.gz
# [OK] ID_HLZXWY.mgb → ID_HLZXWY.fastq.gz
# [OK] ID_HMBLLZ.mgb → ID_HMBLLZ.fastq.gz
# [OK] ID_HMHBTD.mgb → ID_HMHBTD.fastq.gz
# [OK] ID_HMHTVM.mgb → ID_HMHTVM.fastq.gz
# [OK] ID_HMPFKM.mgb → ID_HMPFKM.fastq.gz
# [OK] ID_HNEHFP.mgb → ID_HNEHFP.fastq.gz
# [OK] ID_HNKVMD.mgb → ID_HNKVMD.fastq.gz
# [OK] ID_HNQGCR.mgb → ID_HNQGCR.fastq.gz
# [OK] ID_HNUSGG.mgb → ID_HNUSGG.fastq.gz
# [OK] ID_HOCBQX.mgb → ID_HOCBQX.fastq.gz
# [OK] ID_HOCTRZ.mgb → ID_HOCTRZ.fastq.gz
# [OK] ID_HPDOZK.mgb → ID_HPDOZK.fastq.gz
# [OK] ID_HPFIYU.mgb → ID_HPFIYU.fastq.gz
# [OK] ID_HPXBPI.mgb → ID_HPXBPI.fastq.gz
# [OK] ID_HQASTY.mgb → ID_HQASTY.fastq.gz
# [OK] ID_HQIIEQ.mgb → ID_HQIIEQ.fastq.gz
# [OK] ID_HQMREQ.mgb → ID_HQMREQ.fastq.gz
# [OK] ID_HQQLKV.mgb → ID_HQQLKV.fastq.gz
# [OK] ID_HQQQNL.mgb → ID_HQQQNL.fastq.gz
# [OK] ID_HQXIQW.mgb → ID_HQXIQW.fastq.gz
# [OK] ID_HRBMZQ.mgb → ID_HRBMZQ.fastq.gz
# [OK] ID_HRHZFN.mgb → ID_HRHZFN.fastq.gz
# [OK] ID_HRNFYK.mgb → ID_HRNFYK.fastq.gz
# [OK] ID_HRNMSP.mgb → ID_HRNMSP.fastq.gz
# [OK] ID_HRUKIT.mgb → ID_HRUKIT.fastq.gz
# [OK] ID_HRXBRC.mgb → ID_HRXBRC.fastq.gz
# [OK] ID_HSERIY.mgb → ID_HSERIY.fastq.gz
# [OK] ID_HSFBIK.mgb → ID_HSFBIK.fastq.gz
# [OK] ID_HSPXLB.mgb → ID_HSPXLB.fastq.gz
# [OK] ID_HSTLEV.mgb → ID_HSTLEV.fastq.gz
# [OK] ID_HSYYXK.mgb → ID_HSYYXK.fastq.gz
# [OK] ID_HSZYAZ.mgb → ID_HSZYAZ.fastq.gz
# [OK] ID_HTBIXQ.mgb → ID_HTBIXQ.fastq.gz
# [OK] ID_HTFMKX.mgb → ID_HTFMKX.fastq.gz
# [OK] ID_HTMHDD.mgb → ID_HTMHDD.fastq.gz
# [OK] ID_HTPNNA.mgb → ID_HTPNNA.fastq.gz
# [OK] ID_HTRJON.mgb → ID_HTRJON.fastq.gz
# [OK] ID_HTTFVG.mgb → ID_HTTFVG.fastq.gz
# [OK] ID_HUBZTJ.mgb → ID_HUBZTJ.fastq.gz
# [OK] ID_HUFFIM.mgb → ID_HUFFIM.fastq.gz
# [OK] ID_HVMGNJ.mgb → ID_HVMGNJ.fastq.gz
# [OK] ID_HVSSFY.mgb → ID_HVSSFY.fastq.gz
# [OK] ID_HVYTDS.mgb → ID_HVYTDS.fastq.gz
# [OK] ID_HWAHDI.mgb → ID_HWAHDI.fastq.gz
# [OK] ID_HWJDSR.mgb → ID_HWJDSR.fastq.gz
# [OK] ID_HWOQYF.mgb → ID_HWOQYF.fastq.gz
# [OK] ID_HWUMCJ.mgb → ID_HWUMCJ.fastq.gz
# [OK] ID_HXEJPO.mgb → ID_HXEJPO.fastq.gz
# [OK] ID_HXFPGU.mgb → ID_HXFPGU.fastq.gz
# [OK] ID_HXIDJM.mgb → ID_HXIDJM.fastq.gz
# [OK] ID_HYDLXT.mgb → ID_HYDLXT.fastq.gz
# [OK] ID_HYJWGP.mgb → ID_HYJWGP.fastq.gz
# [OK] ID_HYOXEO.mgb → ID_HYOXEO.fastq.gz
# [OK] ID_HYQCVN.mgb → ID_HYQCVN.fastq.gz
# [OK] ID_HYQXEA.mgb → ID_HYQXEA.fastq.gz
# [OK] ID_HYRYRK.mgb → ID_HYRYRK.fastq.gz
# [OK] ID_HZGNTM.mgb → ID_HZGNTM.fastq.gz
# [OK] ID_HZNPST.mgb → ID_HZNPST.fastq.gz
# [OK] ID_HZOMPE.mgb → ID_HZOMPE.fastq.gz
# [OK] ID_HZTYWI.mgb → ID_HZTYWI.fastq.gz
# [OK] ID_IAXNTO.mgb → ID_IAXNTO.fastq.gz
# [OK] ID_IAYYCN.mgb → ID_IAYYCN.fastq.gz
# [OK] ID_IAYYZM.mgb → ID_IAYYZM.fastq.gz
# [OK] ID_IAZELW.mgb → ID_IAZELW.fastq.gz
# [OK] ID_IBGESQ.mgb → ID_IBGESQ.fastq.gz
# [OK] ID_IBLRWP.mgb → ID_IBLRWP.fastq.gz
# [OK] ID_IBNHUR.mgb → ID_IBNHUR.fastq.gz
# [OK] ID_IBQLGZ.mgb → ID_IBQLGZ.fastq.gz
# [OK] ID_IBZCQS.mgb → ID_IBZCQS.fastq.gz
# [OK] ID_ICEQSO.mgb → ID_ICEQSO.fastq.gz
# [OK] ID_IDDOLY.mgb → ID_IDDOLY.fastq.gz
# [OK] ID_IDGAEG.mgb → ID_IDGAEG.fastq.gz
# [OK] ID_IDKFBN.mgb → ID_IDKFBN.fastq.gz
# [OK] ID_IDMPZW.mgb → ID_IDMPZW.fastq.gz
# [OK] ID_IDNQOC.mgb → ID_IDNQOC.fastq.gz
# [OK] ID_IDUAVH.mgb → ID_IDUAVH.fastq.gz
# [OK] ID_IDXQVH.mgb → ID_IDXQVH.fastq.gz
# [OK] ID_IDZNSC.mgb → ID_IDZNSC.fastq.gz
# [OK] ID_IELNWA.mgb → ID_IELNWA.fastq.gz
# [OK] ID_IEPMFN.mgb → ID_IEPMFN.fastq.gz
# [OK] ID_IERUQE.mgb → ID_IERUQE.fastq.gz
# [OK] ID_IFAUYY.mgb → ID_IFAUYY.fastq.gz
# [OK] ID_IGNYJB.mgb → ID_IGNYJB.fastq.gz
# [OK] ID_IGQWXR.mgb → ID_IGQWXR.fastq.gz
# [OK] ID_IGQXSU.mgb → ID_IGQXSU.fastq.gz
# [OK] ID_IGUHYW.mgb → ID_IGUHYW.fastq.gz
# [OK] ID_IHDKGB.mgb → ID_IHDKGB.fastq.gz
# [OK] ID_IHRHIR.mgb → ID_IHRHIR.fastq.gz
# [OK] ID_IHZXUC.mgb → ID_IHZXUC.fastq.gz
# [OK] ID_IIPMXW.mgb → ID_IIPMXW.fastq.gz
# [OK] ID_IIVRBR.mgb → ID_IIVRBR.fastq.gz
# [OK] ID_IIZEZA.mgb → ID_IIZEZA.fastq.gz
# [OK] ID_IJEMLK.mgb → ID_IJEMLK.fastq.gz
# [OK] ID_IJYVSP.mgb → ID_IJYVSP.fastq.gz
# [OK] ID_IKBAUT.mgb → ID_IKBAUT.fastq.gz
# [OK] ID_IKJMUD.mgb → ID_IKJMUD.fastq.gz
# [OK] ID_IKJNJM.mgb → ID_IKJNJM.fastq.gz
# [OK] ID_IKJQZS.mgb → ID_IKJQZS.fastq.gz
# [OK] ID_IKVEIC.mgb → ID_IKVEIC.fastq.gz
# [OK] ID_ILKLSQ.mgb → ID_ILKLSQ.fastq.gz
# [OK] ID_ILQFMJ.mgb → ID_ILQFMJ.fastq.gz
# [OK] ID_ILRUFY.mgb → ID_ILRUFY.fastq.gz
# [OK] ID_IMCGJT.mgb → ID_IMCGJT.fastq.gz
# [OK] ID_IMMNLY.mgb → ID_IMMNLY.fastq.gz
# [OK] ID_IMQPAX.mgb → ID_IMQPAX.fastq.gz
# [OK] ID_IMSMVK.mgb → ID_IMSMVK.fastq.gz
# [OK] ID_IMTNDM.mgb → ID_IMTNDM.fastq.gz
# [OK] ID_IMTRQS.mgb → ID_IMTRQS.fastq.gz
# [OK] ID_INMAHF.mgb → ID_INMAHF.fastq.gz
# [OK] ID_INPTQL.mgb → ID_INPTQL.fastq.gz
# [OK] ID_INWIXL.mgb → ID_INWIXL.fastq.gz
# [OK] ID_IOYDZY.mgb → ID_IOYDZY.fastq.gz
# [OK] ID_IPBZOJ.mgb → ID_IPBZOJ.fastq.gz
# [OK] ID_IPLYXJ.mgb → ID_IPLYXJ.fastq.gz
# [OK] ID_IPOTMJ.mgb → ID_IPOTMJ.fastq.gz
# [OK] ID_IPZUOK.mgb → ID_IPZUOK.fastq.gz
# [OK] ID_IQAIXE.mgb → ID_IQAIXE.fastq.gz
# [OK] ID_IQGEGJ.mgb → ID_IQGEGJ.fastq.gz
# [OK] ID_IRKICG.mgb → ID_IRKICG.fastq.gz
# [OK] ID_IRMPAY.mgb → ID_IRMPAY.fastq.gz
# [OK] ID_IRPYZT.mgb → ID_IRPYZT.fastq.gz
# [OK] ID_IRQZWM.mgb → ID_IRQZWM.fastq.gz
# [OK] ID_IRRKXN.mgb → ID_IRRKXN.fastq.gz
# [OK] ID_IRWUOF.mgb → ID_IRWUOF.fastq.gz
# [OK] ID_ISILJE.mgb → ID_ISILJE.fastq.gz
# [OK] ID_ISNUQO.mgb → ID_ISNUQO.fastq.gz
# [OK] ID_ISYIVI.mgb → ID_ISYIVI.fastq.gz
# [OK] ID_ITUWCL.mgb → ID_ITUWCL.fastq.gz
# [OK] ID_IUEUGB.mgb → ID_IUEUGB.fastq.gz
# [OK] ID_IUHWQM.mgb → ID_IUHWQM.fastq.gz
# [OK] ID_IUPNAS.mgb → ID_IUPNAS.fastq.gz
# [OK] ID_IVAZKV.mgb → ID_IVAZKV.fastq.gz
# [OK] ID_IVDTZG.mgb → ID_IVDTZG.fastq.gz
# [OK] ID_IVXRDN.mgb → ID_IVXRDN.fastq.gz
# [OK] ID_IWEZBE.mgb → ID_IWEZBE.fastq.gz
# [OK] ID_IWNQAW.mgb → ID_IWNQAW.fastq.gz
# [OK] ID_IWPVZY.mgb → ID_IWPVZY.fastq.gz
# [OK] ID_IWTLUR.mgb → ID_IWTLUR.fastq.gz
# [OK] ID_IXAFEY.mgb → ID_IXAFEY.fastq.gz
# [OK] ID_IXHGKS.mgb → ID_IXHGKS.fastq.gz
# [OK] ID_IXKEDS.mgb → ID_IXKEDS.fastq.gz
# [OK] ID_IXSBLX.mgb → ID_IXSBLX.fastq.gz
# [OK] ID_IXSOUW.mgb → ID_IXSOUW.fastq.gz
# [OK] ID_IYADXI.mgb → ID_IYADXI.fastq.gz
# [OK] ID_IYEAAE.mgb → ID_IYEAAE.fastq.gz
# [OK] ID_IYHCRW.mgb → ID_IYHCRW.fastq.gz
# [OK] ID_IYHGQM.mgb → ID_IYHGQM.fastq.gz
# [OK] ID_IYMGNR.mgb → ID_IYMGNR.fastq.gz
# [OK] ID_IYQUDN.mgb → ID_IYQUDN.fastq.gz
# [OK] ID_IYWRBC.mgb → ID_IYWRBC.fastq.gz
# [OK] ID_IYXKJX.mgb → ID_IYXKJX.fastq.gz
# [OK] ID_IYYIAZ.mgb → ID_IYYIAZ.fastq.gz
# [OK] ID_IZBEYE.mgb → ID_IZBEYE.fastq.gz
# [OK] ID_IZZPMP.mgb → ID_IZZPMP.fastq.gz
# [OK] ID_JACVWA.mgb → ID_JACVWA.fastq.gz
# [OK] ID_JAHMOU.mgb → ID_JAHMOU.fastq.gz
# [OK] ID_JAHWKZ.mgb → ID_JAHWKZ.fastq.gz
# [OK] ID_JAKSWI.mgb → ID_JAKSWI.fastq.gz
# [OK] ID_JAPTKY.mgb → ID_JAPTKY.fastq.gz
# [OK] ID_JAWJMQ.mgb → ID_JAWJMQ.fastq.gz
# [OK] ID_JBGTNW.mgb → ID_JBGTNW.fastq.gz
# [OK] ID_JBOKYD.mgb → ID_JBOKYD.fastq.gz
# [OK] ID_JBQOIY.mgb → ID_JBQOIY.fastq.gz
# [OK] ID_JBWAJA.mgb → ID_JBWAJA.fastq.gz
# [OK] ID_JCIHZJ.mgb → ID_JCIHZJ.fastq.gz
# [OK] ID_JCKAQE.mgb → ID_JCKAQE.fastq.gz
# [OK] ID_JCLHIR.mgb → ID_JCLHIR.fastq.gz
# [OK] ID_JCQNSY.mgb → ID_JCQNSY.fastq.gz
# [OK] ID_JCYNWW.mgb → ID_JCYNWW.fastq.gz
# [OK] ID_JDBIGI.mgb → ID_JDBIGI.fastq.gz
# [OK] ID_JDGWVQ.mgb → ID_JDGWVQ.fastq.gz
# [OK] ID_JDNCVC.mgb → ID_JDNCVC.fastq.gz
# [OK] ID_JEBFZV.mgb → ID_JEBFZV.fastq.gz
# [OK] ID_JEBQAR.mgb → ID_JEBQAR.fastq.gz
# [OK] ID_JEMMCL.mgb → ID_JEMMCL.fastq.gz
# [OK] ID_JEMXNC.mgb → ID_JEMXNC.fastq.gz
# [OK] ID_JESTMG.mgb → ID_JESTMG.fastq.gz
# [OK] ID_JEYXYA.mgb → ID_JEYXYA.fastq.gz
# [OK] ID_JFLNKY.mgb → ID_JFLNKY.fastq.gz
# [OK] ID_JGIMVK.mgb → ID_JGIMVK.fastq.gz
# [OK] ID_JGOJZI.mgb → ID_JGOJZI.fastq.gz
# [OK] ID_JHAFGI.mgb → ID_JHAFGI.fastq.gz
# [OK] ID_JHAJEM.mgb → ID_JHAJEM.fastq.gz
# [OK] ID_JHDHRH.mgb → ID_JHDHRH.fastq.gz
# [OK] ID_JHDOLN.mgb → ID_JHDOLN.fastq.gz
# [OK] ID_JHDTGF.mgb → ID_JHDTGF.fastq.gz
# [OK] ID_JHLBQW.mgb → ID_JHLBQW.fastq.gz
# [OK] ID_JHQDDU.mgb → ID_JHQDDU.fastq.gz
# [OK] ID_JHZMEH.mgb → ID_JHZMEH.fastq.gz
# [OK] ID_JHZZTZ.mgb → ID_JHZZTZ.fastq.gz
# [OK] ID_JIJMNX.mgb → ID_JIJMNX.fastq.gz
# [OK] ID_JINWSS.mgb → ID_JINWSS.fastq.gz
# [OK] ID_JIULZG.mgb → ID_JIULZG.fastq.gz
# [OK] ID_JIWOEE.mgb → ID_JIWOEE.fastq.gz
# [OK] ID_JIYLIG.mgb → ID_JIYLIG.fastq.gz
# [OK] ID_JJCYFR.mgb → ID_JJCYFR.fastq.gz
# [OK] ID_JJPPSW.mgb → ID_JJPPSW.fastq.gz
# [OK] ID_JJSAXQ.mgb → ID_JJSAXQ.fastq.gz
# [OK] ID_JJSJIW.mgb → ID_JJSJIW.fastq.gz
# [OK] ID_JJUOSC.mgb → ID_JJUOSC.fastq.gz
# [OK] ID_JKHEGL.mgb → ID_JKHEGL.fastq.gz
# [OK] ID_JKIWNS.mgb → ID_JKIWNS.fastq.gz
# [OK] ID_JKKNTF.mgb → ID_JKKNTF.fastq.gz
# [OK] ID_JKNQZS.mgb → ID_JKNQZS.fastq.gz
# [OK] ID_JKSRGT.mgb → ID_JKSRGT.fastq.gz
# [OK] ID_JKUYPC.mgb → ID_JKUYPC.fastq.gz
# [OK] ID_JLBZTC.mgb → ID_JLBZTC.fastq.gz
# [OK] ID_JLPCOH.mgb → ID_JLPCOH.fastq.gz
# [OK] ID_JLVUJI.mgb → ID_JLVUJI.fastq.gz
# [OK] ID_JLZUPW.mgb → ID_JLZUPW.fastq.gz
# [OK] ID_JMEMMM.mgb → ID_JMEMMM.fastq.gz
# [OK] ID_JNICQF.mgb → ID_JNICQF.fastq.gz
# [OK] ID_JNKZOH.mgb → ID_JNKZOH.fastq.gz
# [OK] ID_JOOWAV.mgb → ID_JOOWAV.fastq.gz
# [OK] ID_JORFVZ.mgb → ID_JORFVZ.fastq.gz
# [OK] ID_JOYQBY.mgb → ID_JOYQBY.fastq.gz
# [OK] ID_JPAWTM.mgb → ID_JPAWTM.fastq.gz
# [OK] ID_JPCIOL.mgb → ID_JPCIOL.fastq.gz
# [OK] ID_JPFQQG.mgb → ID_JPFQQG.fastq.gz
# [OK] ID_JQOHTM.mgb → ID_JQOHTM.fastq.gz
# [OK] ID_JQUEIJ.mgb → ID_JQUEIJ.fastq.gz
# [OK] ID_JRGMAS.mgb → ID_JRGMAS.fastq.gz
# [OK] ID_JRRJKZ.mgb → ID_JRRJKZ.fastq.gz
# [OK] ID_JRXIOZ.mgb → ID_JRXIOZ.fastq.gz
# [OK] ID_JSCFHK.mgb → ID_JSCFHK.fastq.gz
# [OK] ID_JSEXIX.mgb → ID_JSEXIX.fastq.gz
# [OK] ID_JSSOMH.mgb → ID_JSSOMH.fastq.gz
# [OK] ID_JSXFSJ.mgb → ID_JSXFSJ.fastq.gz
# [OK] ID_JTMNHT.mgb → ID_JTMNHT.fastq.gz
# [OK] ID_JTURXT.mgb → ID_JTURXT.fastq.gz
# [OK] ID_JTXCEH.mgb → ID_JTXCEH.fastq.gz
# [OK] ID_JUGYBT.mgb → ID_JUGYBT.fastq.gz
# [OK] ID_JUKKIX.mgb → ID_JUKKIX.fastq.gz
# [OK] ID_JUKKNI.mgb → ID_JUKKNI.fastq.gz
# [OK] ID_JUXABW.mgb → ID_JUXABW.fastq.gz
# [OK] ID_JUYIST.mgb → ID_JUYIST.fastq.gz
# [OK] ID_JVDHMJ.mgb → ID_JVDHMJ.fastq.gz
# [OK] ID_JVGIRG.mgb → ID_JVGIRG.fastq.gz
# [OK] ID_JWPTNY.mgb → ID_JWPTNY.fastq.gz
# [OK] ID_JWYAIU.mgb → ID_JWYAIU.fastq.gz
# [OK] ID_JXHWDL.mgb → ID_JXHWDL.fastq.gz
# [OK] ID_JXVUSZ.mgb → ID_JXVUSZ.fastq.gz
# [OK] ID_JXWSFG.mgb → ID_JXWSFG.fastq.gz
# [OK] ID_JXXWZU.mgb → ID_JXXWZU.fastq.gz
# [OK] ID_JXZQAO.mgb → ID_JXZQAO.fastq.gz
# [OK] ID_JYCLRL.mgb → ID_JYCLRL.fastq.gz
# [OK] ID_JYEUBM.mgb → ID_JYEUBM.fastq.gz
# [OK] ID_JYOZCU.mgb → ID_JYOZCU.fastq.gz
# [OK] ID_JYPJFJ.mgb → ID_JYPJFJ.fastq.gz
# [OK] ID_JYVFPE.mgb → ID_JYVFPE.fastq.gz
# [OK] ID_JZEQQC.mgb → ID_JZEQQC.fastq.gz
# [OK] ID_JZNHDH.mgb → ID_JZNHDH.fastq.gz
# [OK] ID_JZPBUP.mgb → ID_JZPBUP.fastq.gz
# [OK] ID_JZQHPA.mgb → ID_JZQHPA.fastq.gz
# [OK] ID_JZUZYG.mgb → ID_JZUZYG.fastq.gz
# [OK] ID_KABTDF.mgb → ID_KABTDF.fastq.gz
# [OK] ID_KAFSBH.mgb → ID_KAFSBH.fastq.gz
# [OK] ID_KAHZRD.mgb → ID_KAHZRD.fastq.gz
# [OK] ID_KAIMKV.mgb → ID_KAIMKV.fastq.gz
# [OK] ID_KAYDHA.mgb → ID_KAYDHA.fastq.gz
# [OK] ID_KAYJOI.mgb → ID_KAYJOI.fastq.gz
# [OK] ID_KBDVPB.mgb → ID_KBDVPB.fastq.gz
# [OK] ID_KBPXVR.mgb → ID_KBPXVR.fastq.gz
# [OK] ID_KBTHRU.mgb → ID_KBTHRU.fastq.gz
# [OK] ID_KBXVSU.mgb → ID_KBXVSU.fastq.gz
# [OK] ID_KCBPGE.mgb → ID_KCBPGE.fastq.gz
# [OK] ID_KCEDGE.mgb → ID_KCEDGE.fastq.gz
# [OK] ID_KCFIXL.mgb → ID_KCFIXL.fastq.gz
# [OK] ID_KCJAKX.mgb → ID_KCJAKX.fastq.gz
# [OK] ID_KCQWEK.mgb → ID_KCQWEK.fastq.gz
# [OK] ID_KDDGOU.mgb → ID_KDDGOU.fastq.gz
# [OK] ID_KDIFEO.mgb → ID_KDIFEO.fastq.gz
# [OK] ID_KDKLMY.mgb → ID_KDKLMY.fastq.gz
# [OK] ID_KDKMNW.mgb → ID_KDKMNW.fastq.gz
# [OK] ID_KDNKLW.mgb → ID_KDNKLW.fastq.gz
# [OK] ID_KDQKXH.mgb → ID_KDQKXH.fastq.gz
# [OK] ID_KDQUCE.mgb → ID_KDQUCE.fastq.gz
# [OK] ID_KDSFOX.mgb → ID_KDSFOX.fastq.gz
# [OK] ID_KDYNZV.mgb → ID_KDYNZV.fastq.gz
# [OK] ID_KFDEJO.mgb → ID_KFDEJO.fastq.gz
# [OK] ID_KFDHBW.mgb → ID_KFDHBW.fastq.gz
# [OK] ID_KFDQUJ.mgb → ID_KFDQUJ.fastq.gz
# [OK] ID_KFNGLV.mgb → ID_KFNGLV.fastq.gz
# [OK] ID_KFOVTX.mgb → ID_KFOVTX.fastq.gz
# [OK] ID_KFUTFX.mgb → ID_KFUTFX.fastq.gz
# [OK] ID_KFYCML.mgb → ID_KFYCML.fastq.gz
# [OK] ID_KGAWAZ.mgb → ID_KGAWAZ.fastq.gz
# [OK] ID_KGITLT.mgb → ID_KGITLT.fastq.gz
# [OK] ID_KGKXSZ.mgb → ID_KGKXSZ.fastq.gz
# [OK] ID_KGPWXV.mgb → ID_KGPWXV.fastq.gz
# [OK] ID_KGPZXN.mgb → ID_KGPZXN.fastq.gz
# [OK] ID_KGRRWR.mgb → ID_KGRRWR.fastq.gz
# [OK] ID_KGSYBY.mgb → ID_KGSYBY.fastq.gz
# [OK] ID_KGTYGW.mgb → ID_KGTYGW.fastq.gz
# [OK] ID_KGUAFF.mgb → ID_KGUAFF.fastq.gz
# [OK] ID_KGXSDB.mgb → ID_KGXSDB.fastq.gz
# [OK] ID_KGZWPA.mgb → ID_KGZWPA.fastq.gz
# [OK] ID_KHFWTO.mgb → ID_KHFWTO.fastq.gz
# [OK] ID_KHGSVY.mgb → ID_KHGSVY.fastq.gz
# [OK] ID_KHIBOZ.mgb → ID_KHIBOZ.fastq.gz
# [OK] ID_KHMKGG.mgb → ID_KHMKGG.fastq.gz
# [OK] ID_KHRPDZ.mgb → ID_KHRPDZ.fastq.gz
# [OK] ID_KHSRUO.mgb → ID_KHSRUO.fastq.gz
# [OK] ID_KHXJUH.mgb → ID_KHXJUH.fastq.gz
# [OK] ID_KHYOKC.mgb → ID_KHYOKC.fastq.gz
# [OK] ID_KIBRTS.mgb → ID_KIBRTS.fastq.gz
# [OK] ID_KIPYTE.mgb → ID_KIPYTE.fastq.gz
# [OK] ID_KIVZDA.mgb → ID_KIVZDA.fastq.gz
# [OK] ID_KIWJIL.mgb → ID_KIWJIL.fastq.gz
# [OK] ID_KJAZZR.mgb → ID_KJAZZR.fastq.gz
# [OK] ID_KJBYTP.mgb → ID_KJBYTP.fastq.gz
# [OK] ID_KJFBRZ.mgb → ID_KJFBRZ.fastq.gz
# [OK] ID_KJRPMZ.mgb → ID_KJRPMZ.fastq.gz
# [OK] ID_KJSWVX.mgb → ID_KJSWVX.fastq.gz
# [OK] ID_KKANHE.mgb → ID_KKANHE.fastq.gz
# [OK] ID_KKFIOD.mgb → ID_KKFIOD.fastq.gz
# [OK] ID_KKIIVH.mgb → ID_KKIIVH.fastq.gz
# [OK] ID_KKUBJX.mgb → ID_KKUBJX.fastq.gz
# [OK] ID_KKVQWO.mgb → ID_KKVQWO.fastq.gz
# [OK] ID_KLGLPC.mgb → ID_KLGLPC.fastq.gz
# [OK] ID_KLQGEU.mgb → ID_KLQGEU.fastq.gz
# [OK] ID_KLXBSF.mgb → ID_KLXBSF.fastq.gz
# [OK] ID_KLXYIK.mgb → ID_KLXYIK.fastq.gz
# [OK] ID_KMAJVG.mgb → ID_KMAJVG.fastq.gz
# [OK] ID_KMJFEN.mgb → ID_KMJFEN.fastq.gz
# [OK] ID_KMNSSG.mgb → ID_KMNSSG.fastq.gz
# [OK] ID_KMRXFJ.mgb → ID_KMRXFJ.fastq.gz
# [OK] ID_KMTVOR.mgb → ID_KMTVOR.fastq.gz
# [OK] ID_KMXZSC.mgb → ID_KMXZSC.fastq.gz
# [OK] ID_KNAVRJ.mgb → ID_KNAVRJ.fastq.gz
# [OK] ID_KNQKOH.mgb → ID_KNQKOH.fastq.gz
# [OK] ID_KNWAGQ.mgb → ID_KNWAGQ.fastq.gz
# [OK] ID_KNWIGJ.mgb → ID_KNWIGJ.fastq.gz
# [OK] ID_KNYWGS.mgb → ID_KNYWGS.fastq.gz
# [OK] ID_KONQXF.mgb → ID_KONQXF.fastq.gz
# [OK] ID_KOREUO.mgb → ID_KOREUO.fastq.gz
# [OK] ID_KOXCYX.mgb → ID_KOXCYX.fastq.gz
# [OK] ID_KOXXCZ.mgb → ID_KOXXCZ.fastq.gz
# [OK] ID_KPGTAL.mgb → ID_KPGTAL.fastq.gz
# [OK] ID_KPKAKZ.mgb → ID_KPKAKZ.fastq.gz
# [OK] ID_KPNPDB.mgb → ID_KPNPDB.fastq.gz
# [OK] ID_KQBJFF.mgb → ID_KQBJFF.fastq.gz
# [OK] ID_KQCENB.mgb → ID_KQCENB.fastq.gz
# [OK] ID_KQKNCA.mgb → ID_KQKNCA.fastq.gz
# [OK] ID_KQLRTH.mgb → ID_KQLRTH.fastq.gz
# [OK] ID_KQXLRU.mgb → ID_KQXLRU.fastq.gz
# [OK] ID_KRIYKO.mgb → ID_KRIYKO.fastq.gz
# [OK] ID_KRNFZK.mgb → ID_KRNFZK.fastq.gz
# [OK] ID_KRXYSG.mgb → ID_KRXYSG.fastq.gz
# [OK] ID_KSAEFD.mgb → ID_KSAEFD.fastq.gz
# [OK] ID_KSAOOS.mgb → ID_KSAOOS.fastq.gz
# [OK] ID_KSBEQM.mgb → ID_KSBEQM.fastq.gz
# [OK] ID_KSDTSC.mgb → ID_KSDTSC.fastq.gz
# [OK] ID_KSEFAE.mgb → ID_KSEFAE.fastq.gz
# [OK] ID_KSFAVS.mgb → ID_KSFAVS.fastq.gz
# [OK] ID_KSOPRK.mgb → ID_KSOPRK.fastq.gz
# [OK] ID_KSUTWC.mgb → ID_KSUTWC.fastq.gz
# [OK] ID_KTJQMX.mgb → ID_KTJQMX.fastq.gz
# [OK] ID_KTMYZJ.mgb → ID_KTMYZJ.fastq.gz
# ...
# [OK] ID_QRHEXN.mgb → ID_QRHEXN.fastq.gz
# [OK] ID_QRZZWA.mgb → ID_QRZZWA.fastq.gz
# [OK] ID_QSESQA.mgb → ID_QSESQA.fastq.gz
# [OK] ID_QSGSHH.mgb → ID_QSGSHH.fastq.gz
# [OK] ID_QSVRON.mgb → ID_QSVRON.fastq.gz
# [OK] ID_QTBPXG.mgb → ID_QTBPXG.fastq.gz
# [OK] ID_QTNNPA.mgb → ID_QTNNPA.fastq.gz
# [OK] ID_QTPUJG.mgb → ID_QTPUJG.fastq.gz
# [OK] ID_QTTMED.mgb → ID_QTTMED.fastq.gz
# [OK] ID_QUMMZT.mgb → ID_QUMMZT.fastq.gz
# [OK] ID_QURHKE.mgb → ID_QURHKE.fastq.gz
# [OK] ID_QVYSFM.mgb → ID_QVYSFM.fastq.gz
# [OK] ID_QWHBRI.mgb → ID_QWHBRI.fastq.gz
# [OK] ID_QWQZCT.mgb → ID_QWQZCT.fastq.gz
# [OK] ID_QWVCLM.mgb → ID_QWVCLM.fastq.gz
# [OK] ID_QXKVOW.mgb → ID_QXKVOW.fastq.gz
# [OK] ID_QXLQMR.mgb → ID_QXLQMR.fastq.gz
# [OK] ID_QXSOBJ.mgb → ID_QXSOBJ.fastq.gz
# [OK] ID_QYBWII.mgb → ID_QYBWII.fastq.gz
# [OK] ID_QZAJWB.mgb → ID_QZAJWB.fastq.gz
# [OK] ID_QZDQPX.mgb → ID_QZDQPX.fastq.gz
# [OK] ID_QZGPGU.mgb → ID_QZGPGU.fastq.gz
# [OK] ID_QZIMFY.mgb → ID_QZIMFY.fastq.gz
# [OK] ID_RAWHIQ.mgb → ID_RAWHIQ.fastq.gz
# [OK] ID_RBPJIE.mgb → ID_RBPJIE.fastq.gz
# [OK] ID_RBRTQO.mgb → ID_RBRTQO.fastq.gz
# [OK] ID_RBVWUL.mgb → ID_RBVWUL.fastq.gz
# [OK] ID_RCJRPR.mgb → ID_RCJRPR.fastq.gz
# [OK] ID_RCRXQD.mgb → ID_RCRXQD.fastq.gz
# [OK] ID_RCUVRF.mgb → ID_RCUVRF.fastq.gz
# [OK] ID_RCYKMF.mgb → ID_RCYKMF.fastq.gz
# [OK] ID_RDHURE.mgb → ID_RDHURE.fastq.gz
# [OK] ID_REMOGV.mgb → ID_REMOGV.fastq.gz
# [OK] ID_REULJL.mgb → ID_REULJL.fastq.gz
# [OK] ID_REYPNJ.mgb → ID_REYPNJ.fastq.gz
# [OK] ID_RFKKZX.mgb → ID_RFKKZX.fastq.gz
# [OK] ID_RGCNWA.mgb → ID_RGCNWA.fastq.gz
# [OK] ID_RGJGFW.mgb → ID_RGJGFW.fastq.gz
# [OK] ID_RGTTHZ.mgb → ID_RGTTHZ.fastq.gz
# [OK] ID_RGWSWF.mgb → ID_RGWSWF.fastq.gz
# [OK] ID_RHIKBI.mgb → ID_RHIKBI.fastq.gz
# [OK] ID_RIAKBG.mgb → ID_RIAKBG.fastq.gz
# [OK] ID_RIKUDS.mgb → ID_RIKUDS.fastq.gz
# [OK] ID_RJKRIP.mgb → ID_RJKRIP.fastq.gz
# [OK] ID_RKOHFR.mgb → ID_RKOHFR.fastq.gz
# [OK] ID_RKQIFO.mgb → ID_RKQIFO.fastq.gz
# [OK] ID_RLMZSH.mgb → ID_RLMZSH.fastq.gz
# [OK] ID_RMLFIJ.mgb → ID_RMLFIJ.fastq.gz
# [OK] ID_RMTSMJ.mgb → ID_RMTSMJ.fastq.gz
# [OK] ID_RMWWZJ.mgb → ID_RMWWZJ.fastq.gz
# [OK] ID_RNXHHA.mgb → ID_RNXHHA.fastq.gz
# [OK] ID_ROCPLC.mgb → ID_ROCPLC.fastq.gz
# [OK] ID_ROIPLG.mgb → ID_ROIPLG.fastq.gz
# [OK] ID_RPPEEI.mgb → ID_RPPEEI.fastq.gz
# [OK] ID_RRAGGS.mgb → ID_RRAGGS.fastq.gz
# [OK] ID_RRBFNL.mgb → ID_RRBFNL.fastq.gz
# [OK] ID_RRGPYK.mgb → ID_RRGPYK.fastq.gz
# [OK] ID_RRNXWU.mgb → ID_RRNXWU.fastq.gz
# [OK] ID_RRPSJN.mgb → ID_RRPSJN.fastq.gz
# [OK] ID_RSCGZV.mgb → ID_RSCGZV.fastq.gz
# [OK] ID_RSOEDW.mgb → ID_RSOEDW.fastq.gz
# [OK] ID_RSUGXE.mgb → ID_RSUGXE.fastq.gz
# [OK] ID_RTTNZC.mgb → ID_RTTNZC.fastq.gz
# [OK] ID_RUCXQY.mgb → ID_RUCXQY.fastq.gz
# [OK] ID_RUQJUY.mgb → ID_RUQJUY.fastq.gz
# [OK] ID_RUTEEA.mgb → ID_RUTEEA.fastq.gz
# [OK] ID_RUVILG.mgb → ID_RUVILG.fastq.gz
# [OK] ID_RVUZXG.mgb → ID_RVUZXG.fastq.gz
# [OK] ID_RWIORE.mgb → ID_RWIORE.fastq.gz
# [OK] ID_RWROAQ.mgb → ID_RWROAQ.fastq.gz
# [OK] ID_RWUAEX.mgb → ID_RWUAEX.fastq.gz
# [OK] ID_RWYITO.mgb → ID_RWYITO.fastq.gz
# [OK] ID_RXLXBE.mgb → ID_RXLXBE.fastq.gz
# [OK] ID_RYQIAU.mgb → ID_RYQIAU.fastq.gz
# [OK] ID_RYQIJC.mgb → ID_RYQIJC.fastq.gz
# [OK] ID_SAUEVY.mgb → ID_SAUEVY.fastq.gz
# [OK] ID_SBEIYW.mgb → ID_SBEIYW.fastq.gz
# [OK] ID_SCGIJI.mgb → ID_SCGIJI.fastq.gz
# [OK] ID_SCHCGB.mgb → ID_SCHCGB.fastq.gz
# [OK] ID_SDLDMV.mgb → ID_SDLDMV.fastq.gz
# [OK] ID_SDQRVB.mgb → ID_SDQRVB.fastq.gz
# [OK] ID_SEZDZP.mgb → ID_SEZDZP.fastq.gz
# [OK] ID_SFBLCM.mgb → ID_SFBLCM.fastq.gz
# [OK] ID_SFUMKA.mgb → ID_SFUMKA.fastq.gz
# [OK] ID_SFVMMH.mgb → ID_SFVMMH.fastq.gz
# [OK] ID_SGNHCD.mgb → ID_SGNHCD.fastq.gz
# [OK] ID_SHDIID.mgb → ID_SHDIID.fastq.gz
# [OK] ID_SHDKUX.mgb → ID_SHDKUX.fastq.gz
# [OK] ID_SHQXHO.mgb → ID_SHQXHO.fastq.gz
# [OK] ID_SICHIC.mgb → ID_SICHIC.fastq.gz
# [OK] ID_SIFZMG.mgb → ID_SIFZMG.fastq.gz
# [OK] ID_SJMQBD.mgb → ID_SJMQBD.fastq.gz
# [OK] ID_SLMINA.mgb → ID_SLMINA.fastq.gz
# [OK] ID_SLMYSY.mgb → ID_SLMYSY.fastq.gz
# [OK] ID_SLSSUE.mgb → ID_SLSSUE.fastq.gz
# [OK] ID_SMBIHP.mgb → ID_SMBIHP.fastq.gz
# [OK] ID_SNITZY.mgb → ID_SNITZY.fastq.gz
# [OK] ID_SNMASC.mgb → ID_SNMASC.fastq.gz
# [OK] ID_SOEIUE.mgb → ID_SOEIUE.fastq.gz
# [OK] ID_SPALGS.mgb → ID_SPALGS.fastq.gz
# [OK] ID_SPXUQR.mgb → ID_SPXUQR.fastq.gz
# [OK] ID_SRRBVW.mgb → ID_SRRBVW.fastq.gz
# [OK] ID_STAGDU.mgb → ID_STAGDU.fastq.gz
# [OK] ID_STTQTU.mgb → ID_STTQTU.fastq.gz
# [OK] ID_SUBIBF.mgb → ID_SUBIBF.fastq.gz
# [OK] ID_SUBJSJ.mgb → ID_SUBJSJ.fastq.gz
# [OK] ID_SUTSJH.mgb → ID_SUTSJH.fastq.gz
# [OK] ID_SVISXU.mgb → ID_SVISXU.fastq.gz
# [OK] ID_SXADNZ.mgb → ID_SXADNZ.fastq.gz
# [OK] ID_SXADYW.mgb → ID_SXADYW.fastq.gz
# [OK] ID_SXCZVK.mgb → ID_SXCZVK.fastq.gz
# [OK] ID_SXNPKC.mgb → ID_SXNPKC.fastq.gz
# [OK] ID_SZMORK.mgb → ID_SZMORK.fastq.gz
# [OK] ID_SZOAOB.mgb → ID_SZOAOB.fastq.gz
# [OK] ID_TAXEGB.mgb → ID_TAXEGB.fastq.gz
# [OK] ID_TAXRNS.mgb → ID_TAXRNS.fastq.gz
# [OK] ID_TBIUHC.mgb → ID_TBIUHC.fastq.gz
# [OK] ID_TBMOOG.mgb → ID_TBMOOG.fastq.gz
# [OK] ID_TDWDXA.mgb → ID_TDWDXA.fastq.gz
# [OK] ID_TEJVIO.mgb → ID_TEJVIO.fastq.gz
# [OK] ID_TFMMKM.mgb → ID_TFMMKM.fastq.gz
# [OK] ID_TFOYNB.mgb → ID_TFOYNB.fastq.gz
# [OK] ID_THGEGJ.mgb → ID_THGEGJ.fastq.gz
# [OK] ID_THXTJN.mgb → ID_THXTJN.fastq.gz
# [OK] ID_TIKKOC.mgb → ID_TIKKOC.fastq.gz
# [OK] ID_TIVDWG.mgb → ID_TIVDWG.fastq.gz
# [OK] ID_TJNQXM.mgb → ID_TJNQXM.fastq.gz
# [OK] ID_TKNLZJ.mgb → ID_TKNLZJ.fastq.gz
# [OK] ID_TMGNTU.mgb → ID_TMGNTU.fastq.gz
# [OK] ID_TMLHZP.mgb → ID_TMLHZP.fastq.gz
# [OK] ID_TMSZTO.mgb → ID_TMSZTO.fastq.gz
# [OK] ID_TNDXKP.mgb → ID_TNDXKP.fastq.gz
# [OK] ID_TNTYMU.mgb → ID_TNTYMU.fastq.gz
# [OK] ID_TQWIDM.mgb → ID_TQWIDM.fastq.gz
# [OK] ID_TRMAWK.mgb → ID_TRMAWK.fastq.gz
# [OK] ID_TRZMLZ.mgb → ID_TRZMLZ.fastq.gz
# [OK] ID_TSSLAD.mgb → ID_TSSLAD.fastq.gz
# [OK] ID_TTFIOX.mgb → ID_TTFIOX.fastq.gz
# [OK] ID_TTRXDO.mgb → ID_TTRXDO.fastq.gz
# [OK] ID_TTRXNQ.mgb → ID_TTRXNQ.fastq.gz
# [OK] ID_TUTHLI.mgb → ID_TUTHLI.fastq.gz
# [OK] ID_TVDXTF.mgb → ID_TVDXTF.fastq.gz
# [OK] ID_TVVOGT.mgb → ID_TVVOGT.fastq.gz
# [OK] ID_TWFOOH.mgb → ID_TWFOOH.fastq.gz
# [OK] ID_TWHCGX.mgb → ID_TWHCGX.fastq.gz
# [OK] ID_TWVGUH.mgb → ID_TWVGUH.fastq.gz
# [OK] ID_TXPIAA.mgb → ID_TXPIAA.fastq.gz
# [OK] ID_TZTWZL.mgb → ID_TZTWZL.fastq.gz
# [OK] ID_TZWFLT.mgb → ID_TZWFLT.fastq.gz
# [OK] ID_UABYGB.mgb → ID_UABYGB.fastq.gz
# [OK] ID_UARLKT.mgb → ID_UARLKT.fastq.gz
# [OK] ID_UAVUGI.mgb → ID_UAVUGI.fastq.gz
# [OK] ID_UAZQTA.mgb → ID_UAZQTA.fastq.gz
# [OK] ID_UBEWPC.mgb → ID_UBEWPC.fastq.gz
# [OK] ID_UBLPMY.mgb → ID_UBLPMY.fastq.gz
# [OK] ID_UBTHLE.mgb → ID_UBTHLE.fastq.gz
# [OK] ID_UBVZZX.mgb → ID_UBVZZX.fastq.gz
# [OK] ID_UDICHC.mgb → ID_UDICHC.fastq.gz
# [OK] ID_UFBZOV.mgb → ID_UFBZOV.fastq.gz
# [OK] ID_UFGHMX.mgb → ID_UFGHMX.fastq.gz
# [OK] ID_UGFAUT.mgb → ID_UGFAUT.fastq.gz
# [OK] ID_UGKPXK.mgb → ID_UGKPXK.fastq.gz
# [OK] ID_UHCXKF.mgb → ID_UHCXKF.fastq.gz
# [OK] ID_UHJIFJ.mgb → ID_UHJIFJ.fastq.gz
# [OK] ID_UIFJLE.mgb → ID_UIFJLE.fastq.gz
# [OK] ID_UIJZCT.mgb → ID_UIJZCT.fastq.gz
# [OK] ID_UJNKSW.mgb → ID_UJNKSW.fastq.gz
# [OK] ID_UJTQRO.mgb → ID_UJTQRO.fastq.gz
# [OK] ID_UJWTRH.mgb → ID_UJWTRH.fastq.gz
# [OK] ID_ULYCLD.mgb → ID_ULYCLD.fastq.gz
# [OK] ID_ULZRVC.mgb → ID_ULZRVC.fastq.gz
# [OK] ID_UMYAFU.mgb → ID_UMYAFU.fastq.gz
# [OK] ID_UMZXKJ.mgb → ID_UMZXKJ.fastq.gz
# [OK] ID_UOIPKJ.mgb → ID_UOIPKJ.fastq.gz
# [OK] ID_UOOAPA.mgb → ID_UOOAPA.fastq.gz
# [OK] ID_UOSZZU.mgb → ID_UOSZZU.fastq.gz
# [OK] ID_UPIUVM.mgb → ID_UPIUVM.fastq.gz
# [OK] ID_URHMNJ.mgb → ID_URHMNJ.fastq.gz
# [OK] ID_URMZQG.mgb → ID_URMZQG.fastq.gz
# [OK] ID_URPUJI.mgb → ID_URPUJI.fastq.gz
# [OK] ID_UTASYL.mgb → ID_UTASYL.fastq.gz
# [OK] ID_UUMDMC.mgb → ID_UUMDMC.fastq.gz
# [OK] ID_UVEWHH.mgb → ID_UVEWHH.fastq.gz
# [OK] ID_UVZRRF.mgb → ID_UVZRRF.fastq.gz
# [OK] ID_UWBLYI.mgb → ID_UWBLYI.fastq.gz
# [OK] ID_UWFKLU.mgb → ID_UWFKLU.fastq.gz
# [OK] ID_UXNIQI.mgb → ID_UXNIQI.fastq.gz
# [OK] ID_UYOVRS.mgb → ID_UYOVRS.fastq.gz
# [OK] ID_UYRVKP.mgb → ID_UYRVKP.fastq.gz
# [OK] ID_UZCADS.mgb → ID_UZCADS.fastq.gz
# [OK] ID_UZDQMH.mgb → ID_UZDQMH.fastq.gz
# [OK] ID_VAESYJ.mgb → ID_VAESYJ.fastq.gz
# [OK] ID_VAYSCY.mgb → ID_VAYSCY.fastq.gz
# [OK] ID_VBVWJD.mgb → ID_VBVWJD.fastq.gz
# [OK] ID_VCUOUA.mgb → ID_VCUOUA.fastq.gz
# [OK] ID_VEGQTZ.mgb → ID_VEGQTZ.fastq.gz
# [OK] ID_VEULTD.mgb → ID_VEULTD.fastq.gz
# [OK] ID_VFAACQ.mgb → ID_VFAACQ.fastq.gz
# [OK] ID_VFJROL.mgb → ID_VFJROL.fastq.gz
# [OK] ID_VFYRUF.mgb → ID_VFYRUF.fastq.gz
# [OK] ID_VHSOVP.mgb → ID_VHSOVP.fastq.gz
# [OK] ID_VHVEKC.mgb → ID_VHVEKC.fastq.gz
# [OK] ID_VIFMCA.mgb → ID_VIFMCA.fastq.gz
# [OK] ID_VIFPQA.mgb → ID_VIFPQA.fastq.gz
# [OK] ID_VIJQDQ.mgb → ID_VIJQDQ.fastq.gz
# [OK] ID_VIVXIR.mgb → ID_VIVXIR.fastq.gz
# [OK] ID_VLJTAB.mgb → ID_VLJTAB.fastq.gz
# [OK] ID_VLTTHY.mgb → ID_VLTTHY.fastq.gz
# [OK] ID_VMCDLK.mgb → ID_VMCDLK.fastq.gz
# [OK] ID_VMJTGH.mgb → ID_VMJTGH.fastq.gz
# [OK] ID_VMZNWI.mgb → ID_VMZNWI.fastq.gz
# [OK] ID_VOHMHD.mgb → ID_VOHMHD.fastq.gz
# [OK] ID_VOMBSI.mgb → ID_VOMBSI.fastq.gz
# [OK] ID_VPNYMF.mgb → ID_VPNYMF.fastq.gz
# [OK] ID_VQAROW.mgb → ID_VQAROW.fastq.gz
# [OK] ID_VRFSBR.mgb → ID_VRFSBR.fastq.gz
# [OK] ID_VRIWON.mgb → ID_VRIWON.fastq.gz
# [OK] ID_VRTYHC.mgb → ID_VRTYHC.fastq.gz
# [OK] ID_VSEPYP.mgb → ID_VSEPYP.fastq.gz
# [OK] ID_VUFSVO.mgb → ID_VUFSVO.fastq.gz
# [OK] ID_VVEYSN.mgb → ID_VVEYSN.fastq.gz
# [OK] ID_VWQBGB.mgb → ID_VWQBGB.fastq.gz
# [OK] ID_VWSOLR.mgb → ID_VWSOLR.fastq.gz
# [OK] ID_WACWNE.mgb → ID_WACWNE.fastq.gz
# [OK] ID_WAZIVO.mgb → ID_WAZIVO.fastq.gz
# [OK] ID_WBMCVM.mgb → ID_WBMCVM.fastq.gz
# [OK] ID_WBMMPZ.mgb → ID_WBMMPZ.fastq.gz
# [OK] ID_WCKSIF.mgb → ID_WCKSIF.fastq.gz
# [OK] ID_WCZJPK.mgb → ID_WCZJPK.fastq.gz
# [OK] ID_WECZXK.mgb → ID_WECZXK.fastq.gz
# [OK] ID_WEKMZT.mgb → ID_WEKMZT.fastq.gz
# [OK] ID_WERGBL.mgb → ID_WERGBL.fastq.gz
# [OK] ID_WFEQIT.mgb → ID_WFEQIT.fastq.gz
# [OK] ID_WFFAQL.mgb → ID_WFFAQL.fastq.gz
# [OK] ID_WFREVI.mgb → ID_WFREVI.fastq.gz
# [OK] ID_WGEOSC.mgb → ID_WGEOSC.fastq.gz
# [OK] ID_WHIUUU.mgb → ID_WHIUUU.fastq.gz
# [OK] ID_WHNZHM.mgb → ID_WHNZHM.fastq.gz
# [OK] ID_WIGQLP.mgb → ID_WIGQLP.fastq.gz
# [OK] ID_WITXOA.mgb → ID_WITXOA.fastq.gz
# [OK] ID_WIUMTC.mgb → ID_WIUMTC.fastq.gz
# [OK] ID_WJYUAL.mgb → ID_WJYUAL.fastq.gz
# [OK] ID_WKPTIB.mgb → ID_WKPTIB.fastq.gz
# [OK] ID_WKYNLU.mgb → ID_WKYNLU.fastq.gz
# [OK] ID_WLADEH.mgb → ID_WLADEH.fastq.gz
# [OK] ID_WLAYJI.mgb → ID_WLAYJI.fastq.gz
# [OK] ID_WLNQUD.mgb → ID_WLNQUD.fastq.gz
# [OK] ID_WLOGEG.mgb → ID_WLOGEG.fastq.gz
# [OK] ID_WLRZRX.mgb → ID_WLRZRX.fastq.gz
# [OK] ID_WMWSQL.mgb → ID_WMWSQL.fastq.gz
# [OK] ID_WNGDEB.mgb → ID_WNGDEB.fastq.gz
# [OK] ID_WNJPFT.mgb → ID_WNJPFT.fastq.gz
# [OK] ID_WNMRRC.mgb → ID_WNMRRC.fastq.gz
# [OK] ID_WOZQOQ.mgb → ID_WOZQOQ.fastq.gz
# [OK] ID_WPGKPU.mgb → ID_WPGKPU.fastq.gz
# [OK] ID_WSIIFG.mgb → ID_WSIIFG.fastq.gz
# [OK] ID_WSMTLV.mgb → ID_WSMTLV.fastq.gz
# [OK] ID_WSWMZK.mgb → ID_WSWMZK.fastq.gz
# [OK] ID_WTJDCG.mgb → ID_WTJDCG.fastq.gz
# [OK] ID_WTODMY.mgb → ID_WTODMY.fastq.gz
# [OK] ID_WTYLTM.mgb → ID_WTYLTM.fastq.gz
# [OK] ID_WUGFVI.mgb → ID_WUGFVI.fastq.gz
# [OK] ID_WUSJAO.mgb → ID_WUSJAO.fastq.gz
# [OK] ID_WWPMSP.mgb → ID_WWPMSP.fastq.gz
# [OK] ID_WWVJZB.mgb → ID_WWVJZB.fastq.gz
# [OK] ID_WXZKFS.mgb → ID_WXZKFS.fastq.gz
# [OK] ID_WYUYMY.mgb → ID_WYUYMY.fastq.gz
# [OK] ID_WYXUVZ.mgb → ID_WYXUVZ.fastq.gz
# [OK] ID_WZCZVF.mgb → ID_WZCZVF.fastq.gz
# [OK] ID_XAJLRM.mgb → ID_XAJLRM.fastq.gz
# [OK] ID_XAYTFP.mgb → ID_XAYTFP.fastq.gz
# [OK] ID_XAZALC.mgb → ID_XAZALC.fastq.gz
# [OK] ID_XBBAGH.mgb → ID_XBBAGH.fastq.gz
# [OK] ID_XBLBFN.mgb → ID_XBLBFN.fastq.gz
# [OK] ID_XBWYVZ.mgb → ID_XBWYVZ.fastq.gz
# [OK] ID_XCLVYX.mgb → ID_XCLVYX.fastq.gz
# [OK] ID_XDCBML.mgb → ID_XDCBML.fastq.gz
# [OK] ID_XDFTZZ.mgb → ID_XDFTZZ.fastq.gz
# [OK] ID_XDMVMM.mgb → ID_XDMVMM.fastq.gz
# [OK] ID_XEVQHX.mgb → ID_XEVQHX.fastq.gz
# [OK] ID_XFSLFU.mgb → ID_XFSLFU.fastq.gz
# [OK] ID_XFWNKY.mgb → ID_XFWNKY.fastq.gz
# [OK] ID_XGBUNW.mgb → ID_XGBUNW.fastq.gz
# [OK] ID_XGFKEN.mgb → ID_XGFKEN.fastq.gz
# [OK] ID_XGJMZC.mgb → ID_XGJMZC.fastq.gz
# [OK] ID_XGOABT.mgb → ID_XGOABT.fastq.gz
# [OK] ID_XHBQPF.mgb → ID_XHBQPF.fastq.gz
# [OK] ID_XHTZCI.mgb → ID_XHTZCI.fastq.gz
# [OK] ID_XIEMWG.mgb → ID_XIEMWG.fastq.gz
# [OK] ID_XIIOWV.mgb → ID_XIIOWV.fastq.gz
# [OK] ID_XJRBMI.mgb → ID_XJRBMI.fastq.gz
# [OK] ID_XJYLRF.mgb → ID_XJYLRF.fastq.gz
# [OK] ID_XLDPZS.mgb → ID_XLDPZS.fastq.gz
# [OK] ID_XLDVCN.mgb → ID_XLDVCN.fastq.gz
# [OK] ID_XLUWLV.mgb → ID_XLUWLV.fastq.gz
# [OK] ID_XNGQBZ.mgb → ID_XNGQBZ.fastq.gz
# [OK] ID_XOQVRA.mgb → ID_XOQVRA.fastq.gz
# [OK] ID_XPHJMZ.mgb → ID_XPHJMZ.fastq.gz
# [OK] ID_XREJEU.mgb → ID_XREJEU.fastq.gz
# [OK] ID_XRZHAV.mgb → ID_XRZHAV.fastq.gz
# [OK] ID_XSCGKH.mgb → ID_XSCGKH.fastq.gz
# [OK] ID_XSITII.mgb → ID_XSITII.fastq.gz
# [OK] ID_XTJPEO.mgb → ID_XTJPEO.fastq.gz
# [OK] ID_XUBQXT.mgb → ID_XUBQXT.fastq.gz
# [OK] ID_XUKBYU.mgb → ID_XUKBYU.fastq.gz
# [OK] ID_XVKNSD.mgb → ID_XVKNSD.fastq.gz
# [OK] ID_XVQFWW.mgb → ID_XVQFWW.fastq.gz
# [OK] ID_XVUIVT.mgb → ID_XVUIVT.fastq.gz
# [OK] ID_XXEXGF.mgb → ID_XXEXGF.fastq.gz
# [OK] ID_XXPAOD.mgb → ID_XXPAOD.fastq.gz
# [OK] ID_XXVUFS.mgb → ID_XXVUFS.fastq.gz
# [OK] ID_XXYDBQ.mgb → ID_XXYDBQ.fastq.gz
# [OK] ID_XYJZIJ.mgb → ID_XYJZIJ.fastq.gz
# [OK] ID_XYVFYX.mgb → ID_XYVFYX.fastq.gz
# [OK] ID_XYZFLF.mgb → ID_XYZFLF.fastq.gz
# [OK] ID_XZBUJB.mgb → ID_XZBUJB.fastq.gz
# [OK] ID_XZGAZR.mgb → ID_XZGAZR.fastq.gz
# [OK] ID_YAUMQG.mgb → ID_YAUMQG.fastq.gz
# [OK] ID_YAUXJL.mgb → ID_YAUXJL.fastq.gz
# [OK] ID_YBEXJU.mgb → ID_YBEXJU.fastq.gz
# [OK] ID_YBNOYC.mgb → ID_YBNOYC.fastq.gz
# [OK] ID_YDZRTT.mgb → ID_YDZRTT.fastq.gz
# [OK] ID_YENVJG.mgb → ID_YENVJG.fastq.gz
# [OK] ID_YFCWKA.mgb → ID_YFCWKA.fastq.gz
# [OK] ID_YGISHC.mgb → ID_YGISHC.fastq.gz
# [OK] ID_YIPVQW.mgb → ID_YIPVQW.fastq.gz
# [OK] ID_YJTPWN.mgb → ID_YJTPWN.fastq.gz
# [OK] ID_YKYPOY.mgb → ID_YKYPOY.fastq.gz
# [OK] ID_YMJDMN.mgb → ID_YMJDMN.fastq.gz
# [OK] ID_YMUIJN.mgb → ID_YMUIJN.fastq.gz
# [OK] ID_YMVRHW.mgb → ID_YMVRHW.fastq.gz
# [OK] ID_YNVASN.mgb → ID_YNVASN.fastq.gz
# [OK] ID_YNYVDX.mgb → ID_YNYVDX.fastq.gz
# [OK] ID_YOFONJ.mgb → ID_YOFONJ.fastq.gz
# [OK] ID_YOZYCT.mgb → ID_YOZYCT.fastq.gz
# [OK] ID_YPEUWH.mgb → ID_YPEUWH.fastq.gz
# [OK] ID_YQOIHQ.mgb → ID_YQOIHQ.fastq.gz
# [OK] ID_YRGNQU.mgb → ID_YRGNQU.fastq.gz
# [OK] ID_YSKBBI.mgb → ID_YSKBBI.fastq.gz
# [OK] ID_YTKUUL.mgb → ID_YTKUUL.fastq.gz
# [OK] ID_YTOJQQ.mgb → ID_YTOJQQ.fastq.gz
# [OK] ID_YUEGJH.mgb → ID_YUEGJH.fastq.gz
# [OK] ID_YUXJAI.mgb → ID_YUXJAI.fastq.gz
# [OK] ID_YVMIEX.mgb → ID_YVMIEX.fastq.gz
# [OK] ID_YWABZN.mgb → ID_YWABZN.fastq.gz
# [OK] ID_YWBMIU.mgb → ID_YWBMIU.fastq.gz
# [OK] ID_YXBJNZ.mgb → ID_YXBJNZ.fastq.gz
# [OK] ID_YXVKZR.mgb → ID_YXVKZR.fastq.gz
# [OK] ID_YXWOUQ.mgb → ID_YXWOUQ.fastq.gz
# [OK] ID_YXYPNE.mgb → ID_YXYPNE.fastq.gz
# [OK] ID_YYKHQJ.mgb → ID_YYKHQJ.fastq.gz
# [OK] ID_YYKIRN.mgb → ID_YYKIRN.fastq.gz
# [OK] ID_YYOCYN.mgb → ID_YYOCYN.fastq.gz
# [OK] ID_YZJCKD.mgb → ID_YZJCKD.fastq.gz
# [OK] ID_YZUYOS.mgb → ID_YZUYOS.fastq.gz
# [OK] ID_ZAFLWS.mgb → ID_ZAFLWS.fastq.gz
# [OK] ID_ZANNAE.mgb → ID_ZANNAE.fastq.gz
# [OK] ID_ZBAENY.mgb → ID_ZBAENY.fastq.gz
# [OK] ID_ZCEXAD.mgb → ID_ZCEXAD.fastq.gz
# [OK] ID_ZCOHNC.mgb → ID_ZCOHNC.fastq.gz
# [OK] ID_ZCQPZJ.mgb → ID_ZCQPZJ.fastq.gz
# [OK] ID_ZDAUAT.mgb → ID_ZDAUAT.fastq.gz
# [OK] ID_ZDCEPH.mgb → ID_ZDCEPH.fastq.gz
# [OK] ID_ZDXTOM.mgb → ID_ZDXTOM.fastq.gz
# [OK] ID_ZGPWDB.mgb → ID_ZGPWDB.fastq.gz
# [OK] ID_ZIMSNW.mgb → ID_ZIMSNW.fastq.gz
# [OK] ID_ZIQGRT.mgb → ID_ZIQGRT.fastq.gz
# [OK] ID_ZIZGXX.mgb → ID_ZIZGXX.fastq.gz
# [OK] ID_ZJDYLK.mgb → ID_ZJDYLK.fastq.gz
# [OK] ID_ZKEAEO.mgb → ID_ZKEAEO.fastq.gz
# [OK] ID_ZLFEAA.mgb → ID_ZLFEAA.fastq.gz
# [OK] ID_ZLNIVC.mgb → ID_ZLNIVC.fastq.gz
# [OK] ID_ZLNTXR.mgb → ID_ZLNTXR.fastq.gz
# [OK] ID_ZMEKSI.mgb → ID_ZMEKSI.fastq.gz
# [OK] ID_ZMZPNF.mgb → ID_ZMZPNF.fastq.gz
# [OK] ID_ZNJUOS.mgb → ID_ZNJUOS.fastq.gz
# [OK] ID_ZOAAVW.mgb → ID_ZOAAVW.fastq.gz
# [OK] ID_ZOCTOI.mgb → ID_ZOCTOI.fastq.gz
# [OK] ID_ZOJNBU.mgb → ID_ZOJNBU.fastq.gz
# [OK] ID_ZPHTGI.mgb → ID_ZPHTGI.fastq.gz
# [OK] ID_ZPMIGD.mgb → ID_ZPMIGD.fastq.gz
# [OK] ID_ZPRUAS.mgb → ID_ZPRUAS.fastq.gz
# [OK] ID_ZPVCGH.mgb → ID_ZPVCGH.fastq.gz
# [OK] ID_ZPWGNB.mgb → ID_ZPWGNB.fastq.gz
# [OK] ID_ZQJSXK.mgb → ID_ZQJSXK.fastq.gz
# [OK] ID_ZQPHOL.mgb → ID_ZQPHOL.fastq.gz
# [OK] ID_ZQTHSJ.mgb → ID_ZQTHSJ.fastq.gz
# [OK] ID_ZRCWCQ.mgb → ID_ZRCWCQ.fastq.gz
# [OK] ID_ZRRDIN.mgb → ID_ZRRDIN.fastq.gz
# [OK] ID_ZTKFQH.mgb → ID_ZTKFQH.fastq.gz
# [OK] ID_ZTRJPX.mgb → ID_ZTRJPX.fastq.gz
# [OK] ID_ZUTVQY.mgb → ID_ZUTVQY.fastq.gz
# [OK] ID_ZWFLBS.mgb → ID_ZWFLBS.fastq.gz
# [OK] ID_ZWKWIN.mgb → ID_ZWKWIN.fastq.gz
# [OK] ID_ZWMJPU.mgb → ID_ZWMJPU.fastq.gz
# [OK] ID_ZWUJFO.mgb → ID_ZWUJFO.fastq.gz
# [OK] ID_ZXNUDJ.mgb → ID_ZXNUDJ.fastq.gz
# [OK] ID_ZXTCJH.mgb → ID_ZXTCJH.fastq.gz
# [OK] ID_ZZIPPX.mgb → ID_ZZIPPX.fastq.gz
# [OK] ID_ZZWUCJ.mgb → ID_ZZWUCJ.fastq.gz

# %% [markdown]
# ###  What MPEG-G Did in simple terms
#
# Your `.mgb` file used the MPEG-G standard to store sequencing data efficiently. Here's what happened under the hood:
#
# - **Access Units (AUs)**: Think of these as independent blocks, like packets or video frames. Each AU can be decoded without needing the entire file.
#
# - **Descriptor Streams**:
#   - `SEQUENCE`: These are the DNA letters (A, T, C, G...).
#   - `QUALITY`: Confidence for each base (used to assess sequencing accuracy).
#   - `READ_IDENTIFIER`: Name or ID of each read.
#
# - **Compression Techniques**:
#   - Redundancies in the reads and IDs were removed.
#   - Quality scores may have been quantized or entropy-coded.
#   - Optional reference-based compression could align reads to a known genome and store only differences.
#
# - **Output Format (`.fastq`)**:
#   - This format is standard in genomics: it includes the ID, DNA sequence, and quality scores for each read.
#
# MPEG-G is to genomics what `.mp4` is to video — a way to store large data efficiently without losing critical information.
